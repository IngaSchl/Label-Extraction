# %% [markdown]
# # String similarity by Levenshtein Distance
# This script aims to compute the similarity between strings via Levenshtein Distance (https://en.wikipedia.org/wiki/Levenshtein_distance). It compares the names of streets and places from a current dataset with the ones obtained from the preceding OCR of labels within a historical map.

# %%
# load libraries
import pandas as pd
import geopandas as gpd
import itertools
import Levenshtein
import difflib
import fuzzywuzzy
from fuzzywuzzy import fuzz # compares TWO strings
from fuzzywuzzy import process # compares a string to MULTIPLE other strings

# %% [markdown]
# ## import road network dataset of the city of Hamburg
# Hamburg's road network ('Straßen- und Weggenetz Hamburg') provided via the Transparenzportal Hamburg (source: https://suche.transparenz.hamburg.de/dataset/strassen-und-wegenetz-hamburg-hh-sib9, last update in February 2018) can be obtained via WFS (http://archiv.transparenz.hamburg.de/hmbtgarchive/HMDK/hh_wfs_strassen_und_wegenetz_24055_snap_3.XML). The included layer 'strassennetz-gesamt' is used for further work.

# %% [markdown]
# Before going on working with the dataset, we dissolve it by its street names (column 'strassenname') in QGIS in order to have a single entry for each road:<br><br>
# **QGIS Dissolve**
# - input: strassennetz-gesamt
# - dissolve field: strassenname
# - dissolved: Strassen_Wegenetz_HH_dissolvedByName.shp

# %% [markdown]
# Also with the help of QGIS, a new field 'centroid_s' is created in Strassen_Wegenetz_HH_dissolvedByName.shp where the WKT coordinates of the approximate "centroid" of each resulting (Multi)LineString is stored.
# We compute those centroids as follows:
# - If a road within the original dataset (strassennetz-gesamt) consists of only one linestring, the point at half-length of this linestring is stored as 'centroid_s' in Strassen_Wegenetz_HH_dissolvedByName.shp
# - If a road within the original dataset (strassennetz-gesamt) consists of exactly two linestrings, the interpolated point at half-length over both linestrings is stored as 'centroid_s' in Strassen_Wegenetz_HH_dissolvedByName.shp
# - If a road within the original dataset (strassennetz-gesamt) consists of three or more linestrings, the centroid of their common rectangular bounding box is is stored as 'centroid_s' in Strassen_Wegenetz_HH_dissolvedByName.shp.

# %% [markdown]
# The number of linestrings per street was calculated within the original dataset (strassennetz-gesamt) by counting the number of identical street names (column 'strassenname'):
#
# **QGIS Statistics by category**<br>
# - input vector layer: strassennetz-gesamt
# - field to calculate staistics on: strassenname
# - fields with categories: strassenname

# %% [markdown]
# The field 'count' within the output table lists the number of linestrings per street name.

# %%
# import Straßen- und Wegenetz Hamburg - dissolved by street names
strassennetz = gpd.read_file("data/Strassen_Wegenetz_HH_dissolvedByName.shp")
strassennetz.head()
# Out:
#   von_netzkn nach_netzk  von_statio  bis_statio von_km bis_km klasse  \
# 0  242613570  242613547           0         290   None   None      G
# 1  242515476  242515485           0         112   None   None      G
# 2  232510181  232511346           0          94   None   None      G
# 3  242617259  242617260           0         134   None   None      G
# 4  232510437  232510438           0          20   None   None      G
#
#   strassensc wegenummer              strassenna  ...  ast  europastra  \
# 0       S008     G 5870           Sachsenstraße  ...    0        None
# 1       M175     G 4620                Mewesweg  ...    0        None
# 2       W526      G 258  Walter-Jungleib-Straße  ...    0        None
# 3       M322     G 4759             Mühlenstieg  ...    0        None
# 4       B422      G 938             Boberstraße  ...    0        None
#
#    fahrstreif  fahrstre_1  fahrstre_2 bahnigkeit  geschwindi  \
# 0           1           0           1          1     50 km/h
# 1           1           0           0          1     30 km/h
# 2           1           0           1          1     30 km/h
# 3           0           0           0          0        None
# 4           1           0           1          1     30 km/h
#
#                                              wegeart  \
# 0  Stadtstraße (alle Straßen, die nicht BAB oder ...
# 1  Stadtstraße (alle Straßen, die nicht BAB oder ...
# 2  Stadtstraße (alle Straßen, die nicht BAB oder ...
# 3                                          unbekannt
# 4  Stadtstraße (alle Straßen, die nicht BAB oder ...
#
#                        centroid_s  \
# 0  Point (10.0264443 53.54629129)
# 1  Point (9.87681741 53.53467149)
# 2  Point (9.90921235 53.64648665)
# 3   Point (10.06146359 53.573119)
# 4  Point (9.88700469 53.60026245)
#
#                                             geometry
# 0  LINESTRING (10.02463 53.54566, 10.02484 53.545...
# 1  LINESTRING (9.87609 53.53441, 9.87743 53.53489...
# 2  LINESTRING (9.90934 53.64606, 9.90912 53.64682...
# 3  MULTILINESTRING ((10.05969 53.57264, 10.06349 ...
# 4  LINESTRING (9.88783 53.60103, 9.88780 53.60095...
#
# [5 rows x 24 columns]

# %%
# # get all column names
# for col in strassennetz.columns: 
#     print(col)

# %% [markdown]
# ## clean up the road network dataset
# As we only need the geometry, centroids, and names of the streets we can drop all remaining columns in *strassennetz*.
# As shapefiles have an attribute name limit of 10 characters, we rename the affected columns to improve the readability.

# %%
# extract only the few needed columns
strassennetz = strassennetz[['strassenna','geometry','centroid_s']]
# rename columns
strassennetz=strassennetz.rename(columns={"strassenna":"strassenname",
                                         "centroid_s":"geometry_centroid"})
strassennetz
# Out:
#                                            strassenname  \
# 0                                         Sachsenstraße
# 1                                              Mewesweg
# 2                                Walter-Jungleib-Straße
# 3                                           Mühlenstieg
# 4                                           Boberstraße
# ...                                                 ...
# 9222  Unbenannter Weg Hochwasserschutzanlage St. Pau...
# 9223                                Große Reichenstraße
# 9224                                    Erna-Stahl-Ring
# 9225                                Waltershofer Straße
# 9226                                           Blockweg
#
#                                                geometry  \
# 0     LINESTRING (10.02463 53.54566, 10.02484 53.545...
# 1     LINESTRING (9.87609 53.53441, 9.87743 53.53489...
# 2     LINESTRING (9.90934 53.64606, 9.90912 53.64682...
# 3     MULTILINESTRING ((10.05969 53.57264, 10.06349 ...
# 4     LINESTRING (9.88783 53.60103, 9.88780 53.60095...
# ...                                                 ...
# 9222  MULTILINESTRING ((9.95378 53.54550, 9.95386 53...
# 9223  LINESTRING (9.99370 53.54854, 9.99376 53.54855...
# 9224  MULTILINESTRING ((10.04644 53.62976, 10.04533 ...
# 9225  MULTILINESTRING ((9.89889 53.47866, 9.89897 53...
# 9226  LINESTRING (10.18120 53.47642, 10.18174 53.476...
#
#                     geometry_centroid
# 0      Point (10.0264443 53.54629129)
# 1      Point (9.87681741 53.53467149)
# 2      Point (9.90921235 53.64648665)
# 3       Point (10.06146359 53.573119)
# 4      Point (9.88700469 53.60026245)
# ...                               ...
# 9222   Point (9.95698872 53.54581077)
# 9223   Point (9.99527703 53.54847137)
# 9224  Point (10.04810995 53.62980422)
# 9225   Point (9.90611363 53.49121981)
# 9226  Point (10.18169767 53.47625813)
#
# [9227 rows x 3 columns]

# %% [markdown]
# ## set up the string similarity

# %%
# String similarity  T E S T:
# search for an EXACT buzzword ('Katharinen') in strassenname
strassennetz[strassennetz['strassenname'].str.contains('Katharinen',case=False)] # case insensitive
# Out:
#             strassenname                                           geometry  \
# 3288  Katharinenkirchhof  LINESTRING (9.99389 53.54527, 9.99415 53.54538...
# 3601     Katharinenfleet  MULTILINESTRING ((9.98949 53.54527, 9.98961 53...
# 3697    Katharinenbrücke  LINESTRING (9.99297 53.54581, 9.99309 53.54590...
# 5684    Katharinenstraße  LINESTRING (9.98926 53.54602, 9.98935 53.54604...
#
#                    geometry_centroid
# 3288  Point (9.99467475 53.54556798)
# 3601  Point (9.99141429 53.54525161)
# 3697  Point (9.99313854 53.54594145)
# 5684  Point (9.99111724 53.54596565)

# %% [markdown]
# ### store all street names in a list
# and, at the same time, drop all entries which have an unknown street name. Their 'strassenname' is represented by the prefix "Unbenannte".<br>
# The list format enables an improved comparison for the levenshtein distance which is able to compare a single string (here: a historical street name) to a list of strings (here: *strassen_list*).

# %%
strassen_list = strassennetz['strassenname'].tolist()

# delete all roads containting "Unbenannte"
# if there is this prefix within a road name
substring = "Unbenannte"

for strasse in sorted(strassen_list):
    if substring in strasse:
        strassen_list.remove(strasse)
        
# sort *strassen_list* ascending        
for strasse in sorted(strassen_list):
    print(strasse)
# Out:
# 1. Hafenstraße
# 2. Hafenstraße
# ABC-Straße
# Aalheitengraben
# Aalkrautweg
# Aalort
# Aalwisch
# Aalwischkoppel
# Abbestraße
# Abelke-Bleken-Ring
# Abelskamp
# Abendrothsweg
# Abrahamstraße
# Abteistraße
# Achter Billing
# Achter Lüttmoor
# Achter de Höf
# Achter de Kark
# Achter de Wisch
# Achterdwars
# Achterkamp
# Achtern Barls
# Achtern Born
# Achtern Brack
# Achtern Hoff
# Achtern Hollerbusch
# Achtern Moor
# Achtern Sand
# Achtern Styg
# Achterschlag
# Ackermannstraße
# Ackerstieg
# Ackerweg
# Adalbert-Stifter-Weg
# Adalbertstraße
# Adebarweg
# Adenauerallee
# Adickesstraße
# Adlerhorst
# Adlerstraße
# Admiralitätstraße
# Adolf-Köster-Damm
# Adolf-Wagner-Straße
# Adolf-von-Elm-Hof
# Adolph-Schomacker-Weg
# Adolph-Schönfelder-Straße
# Adolphsbrücke
# Adolphsplatz
# Afrikahöft
# Afrikastraße
# Agathe-Lasch-Weg
# Agathenstraße
# Agnes-Gierck-Weg
# Agnes-Wolffson-Straße
# Agnesstraße
# Ahlbecker Weg
# Ahlfeld
# Ahornallee
# Ahornkamp
# Ahornstraße
# Ahornweg
# Ahrensburger Platz
# Ahrensburger Stieg
# Ahrensburger Straße
# Ahrensburger Weg
# Ahrensfelder Weg
# Ahrenshooper Straße
# Akazienallee
# Akazienweg
# Akeleiweg
# Aladinweg
# Alardusstraße
# Alaskaweg
# Albatrosweg
# Alberichstieg
# Albers-Schönberg-Stieg
# Albers-Schönberg-Weg
# Albershardtweg
# Albershof
# Albert-Einstein-Ring
# Albert-Gebel-Straße
# Albert-Schweitzer-Ring
# Albert-Schäfer-Weg
# Albertine-Assor-Straße
# Albertinenstieg
# Albertiweg
# Albertstraße
# Albrechtstraße
# Aldenrathsweg
# Alemannenweg
# Alexander-Zinn-Straße
# Alexanderstraße
# Alexandra-Stieg
# Alfred-Beit-Weg
# Alfred-Jahncke-Ring
# Alfred-Johann-Levy-Straße
# Alfred-Mahlau-Weg
# Alfred-Wegener-Weg
# Alfredstraße
# Algermissenstraße
# Allende-Platz
# Allensteiner Straße
# Allermöher Deich
# Allermöher Werftstegel
# Allerskehre
# Allhornring
# Allhornstieg
# Allhornweg
# Allmende
# Alma-Ohlmann-Weg
# Alma-Wartenberg-Platz
# Alpenrosenweg
# Alphonsstraße
# Alsenplatz
# Alsenstraße
# Alsterallee
# Alsterarkaden
# Alsterberg
# Alsterblick
# Alsterchaussee
# Alsterdorfer Damm
# Alsterdorfer Markt
# Alsterdorfer Straße
# Alsterfurt
# Alsterglacis
# Alsterhang
# Alsterhöhe
# Alsterkamp
# Alsterkehre
# Alsterkrugchaussee
# Alsterkrüger Kehre
# Alsterredder
# Alsterstieg
# Alsterterrasse
# Alstertor
# Alstertwiete
# Alsterufer
# Alsterweg
# Alsterwiesen
# Alte Aue
# Alte Berner Straße
# Alte Dorfstraße
# Alte Elbgaustraße
# Alte Franzosenheide
# Alte Harburger Elbbrücke
# Alte Holstenstraße
# Alte Kollaustraße
# Alte Königstraße
# Alte Landstraße
# Alte Marsch
# Alte Mühle
# Alte Rabenstraße
# Alte Schleuse
# Alte Schmiede
# Alte Seevestraße
# Alte Sülldorfer Landstraße
# Alte Twiete
# Alte Volksparkstraße
# Alte Weiden
# Alte Wöhr
# Alte Ziegelei
# Altendeichstieg
# Altenfelder Weg
# Altengammer Elbdeich
# Altengammer Hauptdeich
# Altengammer Hausdeich
# Altengammer Marschbahndamm
# Altenhagener Weg
# Altenmoor
# Altenwallbrücke
# Altenwerder Damm
# Altenwerder Elbdeich
# Altenwerder Hauptdeich
# Altenwerder Hauptstraße
# Altenwerder Kirchweg
# Altenwerder Querweg
# Alter Berner Weg
# Alter Botanischer Garten
# Alter Damm
# Alter Deich
# Alter Elbpark
# Alter Fischmarkt
# Alter Fährweg
# Alter Güterbahnhof
# Alter Kirchdeich
# Alter Landweg
# Alter Löschplatz
# Alter Postweg
# Alter Rethedamm
# Alter Schulweg
# Alter Steinweg
# Alter Teichweg
# Alter Wall
# Alter Wandrahm
# Alter Weg
# Alter Zollweg
# Altländer Straße
# Altmannbrücke
# Altmühlweg
# Altonaer Poststraße
# Altonaer Straße
# Altrahlstedter Kamp
# Altrahlstedter Redder
# Altrahlstedter Stieg
# Altstädter Straße
# Altstädter Twiete
# Altwiedenthaler Höhe
# Altwiedenthaler Straße
# Altwiedenthaler Twiete
# Aluminiumstraße
# Alversloweg
# Alwin-Lippert-Weg
# Am Abhang
# Am Alsterfleet
# Am Alten Estesperrwerk
# Am Alten Gericht
# Am Alten Posthaus
# Am Alten Schlachthof
# Am Alten Zoll
# Am Altenwerder Kirchtal
# Am Anger
# Am Anschuß
# Am Anzuchtgarten
# Am Aschenland
# Am Backofen
# Am Bahndamm
# Am Bahngraben
# Am Bahnhof
# Am Ballinkai
# Am Barls
# Am Baum
# Am Baumwall
# Am Beckerkamp
# Am Beedenkamp
# Am Beerbusch
# Am Beerenwald
# Am Berner Wald
# Am Blumenacker
# Am Blumenhof
# Am Born
# Am Botterbarg
# Am Brabandkanal
# Am Bramfelder Zoll
# Am Bredenbek
# Am Brink
# Am Bronzehügel
# Am Brunnenhof
# Am Brünschendiek
# Am Buckhornwald
# Am Burgberg
# Am Callabrack
# Am Centrumshaus
# Am Dalmannkai
# Am Damm
# Am Deichdenkmal
# Am Diebsteich
# Am Diggen
# Am Dorfgraben
# Am Dorfteich
# Am Dornberg
# Am Dulsbergbad
# Am Dänenstein
# Am Ehrenmal
# Am Eichenplatz
# Am Eichenrehmen
# Am Eiland
# Am Eisenwerk
# Am Elbpark
# Am Elbpavillon
# Am Elbtunnel
# Am Elisabethgehölz
# Am Exerzierplatz
# Am Feenteich
# Am Felde
# Am Festungsgraben
# Am Finkenhof
# Am Fleet Venbrook
# Am Frankenberg
# Am Friedhof
# Am Fuchsberg
# Am Fährkanal
# Am Gehegegraben
# Am Gehöckel
# Am Genter Ufer
# Am Gleisdreieck
# Am Gleise
# Am Gnadenberg
# Am Gojenboom
# Am Grasbrookpark
# Am Grenzgraben
# Am Grossen Stein
# Am Großen Dahlen
# Am Grundwasserwerk
# Am Güterbahnhof
# Am Hainholzberg
# Am Hang
# Am Hannoverschen Bahnhof
# Am Hasenberge
# Am Hasenkamp
# Am Heesen
# Am Hegen
# Am Hehsel
# Am Heuckenlock
# Am Hirschpark
# Am Hirtenland
# Am Hohen Feld
# Am Hohen Hause
# Am Hohen Knäbel
# Am Hohen Stege
# Am Holthusenkai
# Am Horner Moor
# Am Husarendenkmal
# Am Hünenstein
# Am Hüßelhus
# Am Inselpark
# Am Internationalen Seegerichtshof
# Am Irrgarten
# Am Isfeld
# Am Jachthafen
# Am Jagen
# Am Jenfelder Bach
# Am Jenfelder Moor
# Am Johannisland
# Am Jägerholz
# Am Kaiserkai
# Am Kampmoor
# Am Karpfenteich
# Am Kiekeberg
# Am Klein Flottbeker Bahnhof
# Am Kleinen Dahlen
# Am Kleinen Kanal
# Am Klingenberg
# Am Knill
# Am Knollgraben
# Am Kratt
# Am Kringel
# Am Kroog
# Am Krähenberg
# Am Kuchenberg
# Am Köhlfleet
# Am Landpflegeheim
# Am Langberg
# Am Langdiek
# Am Langenborn
# Am Langenzug
# Am Lehmberg
# Am Leuchtturm
# Am Licentiatenberg
# Am Lilienberg
# Am Lohmühlenpark
# Am Lohsepark
# Am Luisenhof
# Am Lustberg
# Am Maisfeld
# Am Mariendom
# Am Martensgehölz
# Am Mittelkanal
# Am Moldauhafen
# Am Moor
# Am Moorgürtel
# Am Mühlenbach
# Am Mühlenfeld
# Am Mühlenteich
# Am Neugrabener Bahnhof
# Am Neuländer Baggerteich
# Am Neuländer Gewerbepark
# Am Neumarkt
# Am Nobisteich
# Am Ochsenzoll
# Am Ohlendorffturm
# Am Ohlmoorgraben
# Am Oldenfelder Graben
# Am Oortensiek
# Am Osdorfer Born
# Am Papenbrack
# Am Pavillon
# Am Pfeilshof
# Am Pflug
# Am Pool
# Am Pulverhof
# Am Pumpenkamp
# Am Quickborn
# Am Raakmoorgraben
# Am Radeland
# Am Rathenaupark
# Am Ree
# Am Reiherhorst
# Am Reisenbrook
# Am Rissener Bahnhof
# Am Rosengarten
# Am Rotberg
# Am Röhricht
# Am Saalehafen
# Am Sandauhafen
# Am Sandtorkai
# Am Sandtorpark
# Am Scheinberg
# Am Schießstand
# Am Schiffbeker Berg
# Am Schiffwasser
# Am Schilfpark
# Am Schleusengraben
# Am Schulgarten
# Am Schulwald
# Am Schwarzenberg-Campus
# Am Seggenried
# Am Soldatenfriedhof
# Am Sood
# Am Sooren
# Am Sorgfeld
# Am Sprützmoorgraben
# Am Stadtrand
# Am Staubecken
# Am Stein
# Am Steinlager
# Am Stieglitzhof
# Am Strandkai
# Am Stühm-Nord
# Am Stühm-Süd
# Am Sumpfgraben
# Am Tie
# Am Torbogen
# Am Travehafen
# Am Turnplatz
# Am Veringhof
# Am Vorwerk
# Am Vulkanhafen
# Am Waldesrand
# Am Waldpark
# Am Waldschlößchen
# Am Wall
# Am Wasserturm
# Am Weidengrund
# Am Weiher
# Am Weinberg
# Am Weißenberge
# Am Werder
# Am Wesselhoeftpark
# Am Westerpark
# Am Windhukkai
# Am Ziegelteich
# Am Zollhafen
# Am Öjendorfer See
# Am Überwinterungshafen
# Amalia-Rodrigues-Weg
# Amalie-Dietrich-Stieg
# Amalie-Schoppe-Weg
# Amalie-Sieveking-Weg
# Amalienstraße
# Amandastraße
# Amandus-Stubbe-Straße
# Ambergstraße
# Ambronendamm
# Ameisenkamp
# Ameisweg
# Amelungstraße
# Amerigo-Vespucci-Platz
# Amerikahöft
# Amerikakai
# Amerkamp
# Ammernweg
# Amrumer Knick
# Amselstraße
# Amsinckstraße
# Amsinckufer
# Amsterdamer Kai
# Amtsstraße
# Amundsenstraße
# An de Geest
# An den Dünen
# An den Tannen
# An den Teichwiesen
# An den Wiesen
# An der Alster
# An der Alsterschleife
# An der Alten Süderelbe
# An der Baumschule
# An der Bergkoppel
# An der Berner Au
# An der Blütenmauer
# An der Drosselbek
# An der Eiche
# An der Eisenbahn
# An der Falkenbek
# An der Feldmark
# An der Fischbek
# An der Flottbek
# An der Glinder Au
# An der Hafenbahn
# An der Haidkoppel
# An der Horeburg
# An der Kleiderkasse
# An der Kreisbahn
# An der Landscheide
# An der Lohbek
# An der Lohe
# An der Marienanlage
# An der Mühlenau
# An der Mühlenwettern
# An der Osterbek
# An der Pollhofsbrücke
# An der Rennkoppel
# An der Schleemer Mühle
# An der Schonung
# An der Stadthausbrücke
# An der Steinbek
# An der Sternwarte
# An der Strecke
# An der Twiete
# An der Verbindungsbahn
# An der Walddörferbahn
# Anberg
# Anckelmannsplatz
# Anckelmannstraße
# Anderheitsallee
# Andersenstraße
# Andreas-Knack-Ring
# Andreas-Meyer-Straße
# Andreasberger Weg
# Andreasstraße
# Andreasweg
# Anemonenweg
# Angelikaweg
# Angelnstraße
# Angerburger Straße
# Angerstraße
# Anita-Rée-Straße
# Anita-Sellenschloh-Ring
# Ankerplatz
# Anklamer Ring
# Anna-Hollmann-Weg
# Anna-Lühring-Weg
# Anna-Siemsen-Gang
# Anna-Susanna-Stieg
# Anna-von-Gierke-Ring
# Annaberg
# Anne-Barth-Weg
# Anne-Becker-Ring
# Anne-Frank-Straße
# Anneliese-Tuchel-Weg
# Annemarie-Dose-Park
# Annemarie-Ladewig-Kehre
# Annenstraße
# Anni-Glissmann-Weg
# Annie-Kienast-Straße
# Anny-Tollens-Weg
# Ansgarweg
# Ansorgestraße
# Antilopenstieg
# Anton-Rée-Weg
# Antonie-Möbis-Weg
# Antonistraße
# Antwerpenstraße
# Anzengruberstraße
# Apenrader Straße
# Apfelbeerenring
# Apostelweg
# Apothekergang
# Appelbütteler Weg
# Appelhoff
# Appener Weg
# Appuhnstraße
# Aprikosenweg
# Archenholzstraße
# Archsumer Weg
# Arensweg
# Argentinienbrücke
# Arie-Goral-Platz
# Armbruststraße
# Armgartstraße
# Armin-Clasen-Stieg
# Arminiusstraße
# Arndesstieg
# Arndtstraße
# Arndtweg
# Arnemannstraße
# Arnemannweg
# Arnikastieg
# Arnimstraße
# Arningkai
# Arnisstraße
# Arnkielstraße
# Arno-Holz-Weg
# Arno-Schmidt-Platz
# Arnold-Heise-Straße
# Arnoldistieg
# Arnoldstraße
# Arnswalder Straße
# Aronstabweg
# Arp-Schnitger-Stieg
# Asbeckstraße
# Asbrookdamm
# Aschenputtelstraße
# Ascherring
# Asiakai
# Asmusweg
# Aspersort
# Asserstieg
# Assorweg
# Asternstraße
# Astweg
# Athabaskahöft
# Athabaskakai
# Audorfring
# Aue-Hauptdeich
# Aue-Insel
# Auedeich
# Auenstieg
# Auenstraße
# Auerbachstraße
# Auerhahnweg
# Auersreihe
# Auesiel
# Auf dem Acker
# Auf dem Felde
# Auf dem Kamp
# Auf dem Kollauer Hof
# Auf dem Königslande
# Auf dem Langstücken
# Auf dem Pfahlt
# Auf dem Rapsfeld
# Auf dem Sande
# Auf dem Sülzbrack
# Auf den Bengen
# Auf den Blöcken
# Auf den Wöörden
# Auf der Bojewiese
# Auf der Brandshofer Schleuse
# Auf der Böge
# Auf der Heide
# Auf der Hohen Schaar
# Auf der Höhe
# Auf der Jahnhöhe
# Auf der Koppel
# Auf der Strenge
# August-Bebel-Park
# August-Bebel-Straße
# August-Bolten-Weg
# August-Kirch-Straße
# August-Krogmann-Straße
# August-Lütgens-Park
# August-Macke-Weg
# August-Schlicka-Weg
# August-Somann-Weg
# Augustastraße
# Auguste-Baur-Straße
# Auguste-Schmidt-Weg
# Auguste-Victoria-Kai
# Augustenburger Straße
# Augustenburger Ufer
# Augustenhöh
# Augustenpassage
# Auguststraße
# Aumühler Weg
# Auricher Damm
# Aurikelstieg
# Ausschläger Allee
# Ausschläger Billdeich
# Ausschläger Elbdeich
# Ausschläger Weg
# Australiastraße
# Außenmühlendamm
# Außenmühlenweg
# Avenariusstraße
# Averhoffstraße
# Axel-Springer-Platz
# Azaleenweg
# BAB A1
# BAB A23
# BAB A24
# BAB A25
# BAB A252 abgestuft zur B 75
# BAB A253 abgestuft zur B 75
# BAB A255
# BAB A261
# BAB A7
# Baakenallee
# Baakenhafenbrücke
# Baakenhöft
# Baakenkai
# Baakenpark
# Baakenwerder Straße
# Baarkamp
# Baben Brandheid
# Baben Pfier
# Baben de Heid
# Baben de Möhl
# Babenbrook
# Babendiekstraße
# Babenstieg
# Babenwischenweg
# Bacherweg
# Bachstelzenweg
# Bachstraße
# Bachstücken
# Bachstückenring
# Bachtwiete
# Backhauskoppel
# Badestraße
# Baedekerbogen
# Baererstraße
# Baggesenstieg
# Bahngärten
# Bahnhofsinsel
# Bahnhofspassage
# Bahnhofsvorplatz Neuwiedenthal
# Bahrenfelder Chaussee
# Bahrenfelder Kirchenweg
# Bahrenfelder Marktplatz
# Bahrenfelder Steindamm
# Bahrenfelder Straße
# Bahrstraße
# Balduinstraße
# Balduintreppe
# Balkenstücken
# Ballerstaedtweg
# BallinPark
# Ballindamm
# Ballinkai
# Balthasarweg
# Baltrumer Weg
# Bandelstraße
# Bandkampsweg
# Bandwirkerstraße
# Banksstraße
# Bannwarthstraße
# Bansenstraße
# Bansgraben
# Bantschowstraße
# Barcastraße
# Barckhusendamm
# Barenbleek
# Barenkrug
# Bargackerdamm
# Bargfelder Weg
# Bargfredestraße
# Bargkoppelstieg
# Bargkoppelweg
# Bargstedgasse
# Bargteheider Straße
# Bargweg
# Barkendal
# Barkenkamp
# Barkenkoppel
# Barkhausenweg
# Barkhof
# Barlachstraße
# Barlskamp
# Barmbeker Markt
# Barmbeker Straße
# Barmbeker-Ring-Brücke
# Barmstedter Weg
# Barmwisch
# Barnerstraße
# Baron-Voght-Straße
# Barsbütteler Straße
# Barsbütteler Weg
# Bartelssaal
# Bartelsstraße
# Bartensteiner Weg
# Bartholomäusstraße
# Bartiner Weg
# Bartmanns Treppe
# Basaltweg
# Basedowstraße
# Basselweg
# Bataverweg
# Baubürgerweg
# Bauerberg
# Bauerbergweg
# Bauernholztal
# Bauernrosenweg
# Bauernstegel
# Bauernvogtkoppel
# Bauernweide
# Baumacker
# Baumanns Treppe
# Baumeisterstraße
# Baumfalkenweg
# Baumkamp
# Baumläuferweg
# Baumpieperweg
# Baumschulenweg
# Baumstraße
# Baumtwiete
# Baumwall
# Baumweg
# Baurs Park
# Baurs Weg
# Baurstraße
# Bausenhof
# Baustraße
# Bauvereinsweg
# Bauwiesenstraße
# Baxmannstraße
# Baxmannweg
# Bayernweg
# Beatles-Platz
# Bebelallee
# Bechsteinweg
# Beckedorfer Straße
# Beckerberg
# Beckermannweg
# Beckers Treppe
# Beckmannstraße
# Beckstedtweg
# Beckstraße
# Bedarfsumleitungen A 261 (ND)
# Bedarfsumleitungen A 39 (ND)
# Bedarfsumleitungen A 7 (ND)
# Bedarfsumleitungen A1 (SH)
# Bedarfsumleitungen A23 (SH)
# Bedarfsumleitungen A24 (SH)
# Bedarfsumleitungen A7 (SH)
# Beensroaredder
# Beentkamp
# Beerboomstücken
# Beerbuschredder
# Beerbuschring
# Beerbuschstieg
# Beerenberg
# Beerenhain
# Beerenhöhe
# Beerentaltrift
# Beerentaltwiete
# Beerentalweg
# Beerenweg
# Beerenwinkel
# Beetenweg
# Beethovenallee
# Beethovenstraße
# Beetsweg
# Begel
# Begonienweg
# Behaimweg
# Behnkenkammer
# Behnsrade
# Behnstraße
# Behrensstraße
# Behringstraße
# Behrkampsweg
# Behrmannplatz
# Bei Schuldts Stift
# Bei St. Annen
# Bei St. Ansgar
# Bei St. Johannis
# Bei dem Neuen Krahn
# Bei den Boltwiesen
# Bei den Düneneichen
# Bei den Heidehütten
# Bei den Höfen
# Bei den Kirchhöfen
# Bei den Mühren
# Bei den St. Pauli-Landungsbrücken
# Bei den Tennisplätzen
# Bei den Wandseterrassen
# Bei den Zelten
# Bei der Alten Börse
# Bei der Apostelkirche
# Bei der Bergwettern
# Bei der Blauen Brücke
# Bei der Christuskirche
# Bei der Flottbeker Kirche
# Bei der Flottbeker Mühle
# Bei der Friedenseiche
# Bei der Friedenskirche
# Bei der Grünen Brücke
# Bei der Hammer Kirche
# Bei der Hauptfeuerwache
# Bei der Hopfenkarre
# Bei der Johanniskirche
# Bei der Lutherbuche
# Bei der Martinskirche
# Bei der Matthäuskirche
# Bei der Neuen Münze
# Bei der Osterkirche
# Bei der Paul-Gerhardt-Kirche
# Bei der Pauluskirche
# Bei der Petrikirche
# Bei der Pulvermühle
# Bei der Reitbahn
# Bei der Rolandsmühle
# Bei der Schilleroper
# Bei der Schmiede
# Bei der St. Gertrudkirche
# Bei der Stadtwassermühle
# Bei der Vogelstange
# Bei der Windmühle
# Bei der Wollkämmerei
# Bei der Ziegelei
# Beidenfletweg
# Beim Alten Gaswerk
# Beim Alten Schützenhof
# Beim Alten Waisenhause
# Beim Amsinckpark
# Beim Andreasbrunnen
# Beim Avenberg
# Beim Bergwerk
# Beim Berliner Tor
# Beim Bieberhof
# Beim Brinkmannschen Park
# Beim Dorfgraben
# Beim Dorfkrug
# Beim Elbkurhaus
# Beim Erdkamp
# Beim Farenland
# Beim Gesundbrunnen
# Beim Grootsee
# Beim Großen Teich
# Beim Grünen Jäger
# Beim Hammer Marktplatz
# Beim Hirtenkaten
# Beim Jacobjstift
# Beim Kraftwerk
# Beim Kugelwechsel
# Beim Lehmbrook
# Beim Lüdmoorgraben
# Beim Opferstein
# Beim Pachthof
# Beim Rauhen Hause
# Beim Riesenstein
# Beim Saaren
# Beim Sandbrack
# Beim Schillingstift
# Beim Schlump
# Beim Schröderschen Hof
# Beim Schäferhof
# Beim Strohhause
# Beim Trichter
# Beim Wilhelmsburger Wasserturm
# Beim Ziegelhof
# Beimoorstraße
# Beisserstraße
# Bekassinenau
# Bekkamp
# Bekkampsweg
# Bekkoppeln
# Bekstück
# Bekweg
# Bekwisch
# Belemannweg
# Belgarder Straße
# Bellealliancestraße
# Bellerbek
# Bellevue
# Bellmannstraße
# Beltgens Garten
# Benatzkyweg
# Bendestorfer Ring
# Bendixensweg
# Bengelsdorfstieg
# Bengelsdorfstraße
# Benittstraße
# Bennigsenstraße
# Benselweg
# Benzenbergweg
# Benzstraße
# Berberweg
# Berchtungweg
# Berenberg-Gossler-Weg
# Bergdoltweg
# Bergedorfer Heerweg
# Bergedorfer Markt
# Bergedorfer Schloßstraße
# Bergedorfer Straße
# Bergheide
# Bergiusstraße
# Bergkoppelweg
# Bergmannring
# Bergmannstraße
# Bergstedter Alte Landstraße
# Bergstedter Chaussee
# Bergstedter Kirchenstraße
# Bergstedter Markt
# Bergstieg
# Bergstraße
# Bergstraße (Straße im Bereich Friedhof Ohlsdorf keine amtl. Benennung!)
# Bergwetternweg
# Bergwinkel
# Berkefeldweg
# Berlepschweg
# Berliner Platz
# Berliner Tor
# Berliner Ufer
# Berlinertordamm
# Bernadottestraße
# Bernburger Weg
# Berner Allee
# Berner Brücke
# Berner Chaussee
# Berner Gutsweg
# Berner Heerweg
# Berner Koppel
# Berner Stieg
# Berner Straße
# Berner Weg
# Bernhard-Nocht-Straße
# Bernsteinweg
# Bernstorffstraße
# Bernwardkoppel
# Bert-Kaempfert-Platz
# Berta-Kröger-Platz
# Bertha-Keyser-Weg
# Bertha-Uhl-Kamp
# Berthastraße
# Berthold-Schwarz-Straße
# Bertrand-Russell-Straße
# Berzeliusstraße
# Beselerplatz
# Beselerstraße
# Besenbinderhof
# Besenheide
# Besenreeg
# Besselstraße
# Bessemerweg
# Bessenkamp
# Bethesdastraße
# Bettinastieg
# Betty-Heine-Stieg
# Betty-Levi-Passage
# Beutnerring
# Bevenser Weg
# Beyestieg
# Bi de Börner
# Bi de Dörpsmeed
# Bi'n Achterbarg
# Bickbargen
# Bieberstraße
# Biedermannplatz
# Biehlweg
# Bielfeldtstraße
# Bienenbusch
# Bienenkamp
# Biernatzkistraße
# Biesterfeldweg
# Bilenbarg
# Bilenbargstieg
# Billbrookdeich
# Billgrabendeich
# Billhafen-Löschplatz
# Billhorner Brückenstraße
# Billhorner Deich
# Billhorner Kanalstraße
# Billhorner Mühlenweg
# Billhorner Röhrendamm
# Billrothstraße
# Billstedter Bahnstieg
# Billstedter Hauptstraße
# Billstedter Mühlenweg
# Billstedter Platz
# Billstieg
# Billstraße
# Billufer
# Billwerder Billdeich
# Billwerder Kirchensteg
# Billwerder Neuer Deich
# Billwerder Ring
# Billwerder Steindamm
# Billwerder Straße
# Billwiese
# Bilsenkrautweg
# Bilser Stieg
# Bilser Straße
# Binderstraße
# Bindfeldweg
# Binnenfeld
# Binnenfeldredder
# Binnenhafenbrücke
# Binsbarg
# Binsengrund
# Binsenkoppel
# Binsenort
# Binsenweg
# Birckholtzweg
# Birkenallee
# Birkenau
# Birkenbruch
# Birkengrund
# Birkenhain
# Birkenhöhe
# Birkenkoppel
# Birkenredder
# Birkenstieg
# Birkenweg
# Birkhahnweg
# Birnweg
# Birrenkovenallee
# Birtstraße
# Bisamweg
# Bismarckstein
# Bismarckstraße
# Bispinger Weg
# Bissingstraße
# Bittcherweg
# Björnsonweg
# Blakshörn
# Blangendöör
# Blankenburger Weg
# Blankeneser Bahnhofstraße
# Blankeneser Hauptstraße
# Blankeneser Kirchenweg
# Blankeneser Landstraße
# Blaubeerenstieg
# Blaukehlchenweg
# Blaukissenstieg
# Blaumeisenweg
# Blechschmidtstraße
# Bleckering
# Bleichenbrücke
# Bleichensteg
# Bleicherstraße
# Bleichertwiete
# Bleicherweg
# Bleickenallee
# Bleßhuhnweg
# Blinckmannweg
# Blockweg
# Blohmstraße
# Blomeweg
# Blomkamp
# Blostwiete
# Blosweg
# Blumenau
# Blumeneschenhof
# Blumenpfad
# Blumensand
# Blumenstieg
# Blumenstraße
# Blumenweg
# Blutbuchenweg
# Blättnerring
# Blöckhorn
# Blücherstraße
# Blütenstieg
# Blütenweg
# Boberger Anger
# Boberger Aue
# Boberger Drift
# Boberger Furt
# Boberger Furtweg
# Boberger Höhe
# Boberger Lohe
# Boberger Straße
# Boberstraße
# Bobzienweg
# Bochumer Weg
# Bockhorst
# Bockhorster Höhe
# Bockhorster Weg
# Bockrisweg
# Bocksberg
# Bodelschwinghstraße
# Bodemannweg
# Bodenstedtstraße
# Bodestraße
# Bodo-Sellhorn-Weg
# Boehringerweg
# Bogenallee
# Bogenstraße
# Bohlens Allee
# Bohlenweg
# Bohnstraße
# Boizenburger Weg
# Bojendamm
# Bojeweg
# Boldtstraße
# Bollweg
# Boltenhagener Straße
# Boltens Allee
# Boltwischen
# Bombaybrücke
# Bondenwald
# Bonhoefferstraße
# Bonifatiusplatz
# Bonifatiusstraße
# Boninstraße
# Bonnéweg
# Bonusstraße
# Bookholtstwiete
# Bookweetenkamp
# Boomhof
# Boothsweg
# Borchardsheide
# Borchersweg
# Borchertring
# Borchertstraße
# Borchlingweg
# Bordesholmer Straße
# Borgesch
# Borgfelder Allee
# Borgfelder Stieg
# Borgfelder Straße
# Borghorster Elbdeich
# Borghorster Hauptdeich
# Borgstücken
# Borgweg
# Borkenweg
# Borkumer Weg
# Bornbachstieg
# Bornbergweg
# Bornblick
# Bornbrook
# Borndeel
# Borndiek
# Bornemannstraße
# Borner Stieg
# Bornheide
# Bornholdts Treppe
# Bornkamp
# Bornkampsweg
# Bornmoor
# Bornmühlenweg
# Bornsteinplatz
# Bornstraße
# Bornwisch
# Borracks Weg
# Borselstraße
# Borsigstraße
# Borsteler Bogen
# Borsteler Chaussee
# Borstelmannsweg
# Borstels Ende
# Boschstraße
# Boskopstieg
# Bossardstraße
# Bosselkamp
# Bostelbeker Damm
# Bostelbeker Hauptdeich
# Bostelreihe
# Botenstieg
# Bothmannstraße
# Bovestraße
# Boysenkamp
# Boysheide
# Boystwiete
# Boytinstraße
# Bozenhardweg
# Boßdorfstraße
# Braamheide
# Braamkamp
# Braamkoppelweg
# Braamwisch
# Brabandstraße
# Brachetweg
# Brachland
# Brachvogelweg
# Brack
# Brackdamm
# Brackhövel
# Brackstraße
# Brackweg
# Brahmsallee
# Brambuschweg
# Bramfelder Chaussee
# Bramfelder Dorfplatz
# Bramfelder Drift
# Bramfelder Redder
# Bramfelder Straße
# Bramfelder Weg
# Bramkoppel
# Brammerhäger Damm
# Brammerhörn
# Bramweg
# Brandenburger Brücke
# Brandenburger Straße
# Brander Weg
# Brandesstraße
# Brandfurt
# Brandheide
# Brandorffweg
# Brandsende
# Brandshofer Deich
# Brandstwiete
# Brandstücken
# Brandts Weg
# Brauerknechtgraben
# Brauhausstieg
# Brauhausstraße
# Braune Brücke
# Braunlager Weg
# Braunsberger Weg
# Braunschweiger Straße
# Braunstieg
# Braußpark
# Breckwoldtstraße
# Bredenbekhörn
# Bredenbekkamp
# Bredenbekstieg
# Bredenbekstraße
# Bredenbergsweg
# Bredeneschredder
# Bredengrund
# Bredensand
# Bredenstücken
# Bredenwinkel
# Bredkamp
# Bredowbrücke
# Bredowstraße
# Bredstedter Straße
# Breedenweg
# Brehmweg
# Breite Straße
# Breitenbachweg
# Breitenfelder Straße
# Breiter Gang
# Breitscheidweg
# Brekelbaums Park
# Bremer Kai
# Bremer Reihe
# Bremer Straße
# Bremers Weg
# Brennerhof
# Brennerhofbrücke
# Brennerstraße
# Brennhauskoppel
# Brentanostraße
# Breslauer Straße
# Brieger Weg
# Briggweg
# Brigittenstraße
# Brillkamp
# Brinkstücken
# Brockdorffstraße
# Brockesstraße
# Brockhausweg
# Brockmannsweg
# Brodersenstraße
# Brodersweg
# Brodschrangen
# Brombeerweg
# Brombergstieg
# Broockkampsweg
# Brook
# Brookdamm
# Brookdeich
# Brookkehre
# Brooksbrücke
# Brooksheide
# Brookstraße
# Brooktorkai
# Brooktorpromenade
# Brookwisch
# Brotkamp
# Brotkoppel
# Bruchloh
# Brucknerstraße
# Bruhnrögenredder
# Bruhnsallee
# Bruktererweg
# Brummelhorn
# Brummerredder
# Brummerskamp
# Brunckhorstweg
# Brunhildstraße
# Brunnenhofstraße
# Brunnenkoppel
# Brunnenstieg
# Bruno-Georges-Platz
# Bruno-Lauenroth-Weg
# Bruno-Tesch-Platz
# Brunsberg
# Brunsdorfer Weg
# Brunskamp
# Brunskrogweg
# Brunsstraße
# Brunsteenredder
# Brunsteenweg
# Bräsigweg
# Brödermannsweg
# Bröers Treppe
# Brücke des 17. Juni
# Brückenstieg
# Brückwiesenstraße
# Brüder-Hornemann-Straße
# Brüderstraße
# Brüdtweg
# Brüggemannsweg
# Brügkamp
# Brünschentwiete
# Bubendeyweg
# Bublitzer Straße
# Buceriusstraße
# Bucheckerweg
# Buchenallee
# Buchenhof
# Buchenkamp
# Buchenring
# Buchenstieg
# Buchenstraße
# Buchenweg
# Buchfinkenweg
# Buchheisterstraße
# Buchholzer Weg
# Buchnerweg
# Buchsbaumweg
# Buchtstraße
# Buchwaldstieg
# Buchwaldstraße
# Buckhoop
# Buckhorn
# Buckhornstieg
# Budapester Straße
# Buddenbrookweg
# Buddestraße
# Buekweg
# Buenos-Aires-Kai
# Bugdahnstraße
# Bugenhagenstraße
# Bukampsmoor
# Bulckestraße
# Bullenbarg
# Bullenhuser Damm
# Bullenkoppel
# Bullenredder
# Bullerdeich
# Bullertweg
# Bullnwisch
# Bullskamp
# Bult
# Bunatwiete
# Bundesstraße
# Bundesweg
# Bundsensweg
# Bunsenstraße
# Buntspechtweg
# Bunzlauer Straße
# Burbekstraße
# Burchardkai
# Burchardplatz
# Burchardstraße
# Burggarten
# Burggraben
# Burgstraße
# Burgunderweg
# Burgwedel
# Burgwedelkamp
# Burgwedelstieg
# Burgwedeltwiete
# Burgweide
# Burmesterstraße
# Busanbrücke
# Busanlage Am Neugrabenener Bahnhof,S
# Busanlage Am Neugrabener Bahnhof, N
# Busanlage Harburger Chaussee
# Busanlage Nordalbingerweg
# Busanlage Stormarnplatz
# Busanlage Van-der-Smissen-Straße
# Busbahnhof (ZOB) Hamburg
# Busbahnhof Bergedorf
# Busbahnhof Billstedter Platz
# Busbahnhof Burgstraße
# Busbahnhof Burgwedel
# Busbahnhof Eidelstedter Platz
# Busbahnhof Harburg
# Busbahnhof Neuwiedenthal
# Busbahnhof Rahlstedt
# Busbahnhof Tibarg
# Busbahnhof Wandsbek (ZOB)
# Busbahnhof Wentzelplatz
# Busbahnhof Wilhelmsburg (S-Bahn)
# Busbrookhöhe
# Buscher Weg
# Buschhägen
# Buschhövel
# Buschkamp
# Buschkoppel
# Buschredder
# Buschrosenweg
# Buschweide
# Buschwerder Hauptdeich
# Buschwerder Winkel
# Bussardweg
# Bussestraße
# Butendeichsweg
# Butenfeld
# Butenkamp
# Butenwarf
# Butjadinger Weg
# Butterbauernstieg
# Buttstraße
# Buurkamp
# Buurredder
# Buurstieg
# Buxtehuder Straße
# Bäckerbreitergang
# Bäckerstieg
# Bärenallee
# Bärenhof
# Bärenhäuterweg
# Bärentraubenweg
# Bärwalder Straße
# Böckelweg
# Böcklerstraße
# Böcklinstraße
# Böckmannstraße
# Böge
# Böhmersweg
# Böhmestraße
# Böhmkenstraße
# Böhrsweg
# Bökenbarg
# Bökenkamp
# Bökentwiete
# Bömelburgstieg
# Bömelburgweg
# Bönningstedter Weg
# Börnestraße
# Börsenbrücke
# Bötelkamp
# Böttcherkamp
# Böttcherkoppel
# Böttgerstraße
# Böverstland
# Bülaustraße
# Bülowstieg
# Bülowstraße
# Bültenblick
# Bültenkoppel
# Bültenmoor
# Büngerweg
# Bünte
# Bürgerstraße
# Bürgerweide
# Büringstwiete
# Büschstraße
# Büttskamp
# Cafeastraße
# Caffamacherreihe
# Caprivistraße
# Caracasweg
# Carl-Bremer-Ring
# Carl-Cohn-Straße
# Carl-Ihrke-Weg
# Carl-Legien-Platz
# Carl-Petersen-Straße
# Carl-Stamm-Park
# Carl-von-Ossietzky-Platz
# Carlebachstraße
# Carlssonweg
# Carpserweg
# Carsten-Fock-Weg
# Carsten-Meyn-Weg
# Carsten-Rehder-Straße
# Carsten-Reimers-Ring
# Carsten-Reimers-Stieg
# Caspar-Voght-Straße
# Catharina-Fellendorf-Straße
# Celler Weg
# Celsiusweg
# Chamissoweg
# Chapeaurougeweg
# Charitas-Bischoff-Treppe
# Charlie-Mills-Straße
# Charlotte-Mügge-Weg
# Charlotte-Niese-Straße
# Charlottenburger Straße
# Charlottenstraße
# Chateauneufstraße
# Chaukenweg
# Chemnitzstraße
# Cheruskerweg
# Chicagokai
# Chicagostraße
# Chilekai
# Christa-Siems-Park
# Christenweg
# Christian-August-Weg
# Christian-F.-Hansen-Straße
# Christian-Förster-Straße
# Christian-Koch-Weg
# Christinenstraße
# Christoph-Cordes-Straße
# Christoph-Probst-Weg
# Christopher-Harms-Weg
# Christrosenweg
# Chrysanderstraße
# Cilli-Cohrs-Weg
# City-Hof-Passage
# Clasingstraße
# Classenstieg
# Classenweg
# Claudiusstieg
# Claudiusstraße
# Claus-Ferck-Straße
# Clematisweg
# Clemens-Schultz-Straße
# Colonnaden
# Comeniusplatz
# Communionsweg
# Compeweg
# Congressplatz
# Contastraße
# Conventstraße
# Conzestraße
# Cord-Dreyer-Weg
# Cordesallee (Straße im Bereich Friedhof Ohlsdorf keine amtl. Benennung!)
# Cordesweg
# Cordsstraße
# Corduaweg
# Corinthstraße
# Cornehlsweg
# Cornelia-Harte-Straße
# Corneliusstraße
# Corthumstraße
# Corveystraße
# Coseler Twiete
# Cottaweg
# Cranachplatz
# Cranachstraße
# Cranzer Elbdeich
# Cranzer Hauptdeich
# Cremon
# Culinstraße
# Curienstraße
# Curschmannstraße
# Curslacker Brückendamm
# Curslacker Deich
# Curslacker Heerweg
# Curslacker Kirchenbrücke
# Curslacker Neuer Deich
# Curt-Bär-Weg
# Curt-Goetz-Straße
# Curtiusweg
# Cuxhavener Straße
# Cäcilienstraße
# César-Klein-Ring
# Dachsberg
# Daerstorfer Weg
# Dag-Hammarskjöld-Brücke
# Dag-Hammarskjöld-Platz
# Dagebüller Weg
# Dahlemer Ring
# Dahlengrund
# Dahlenholz
# Dahlenhöhe
# Dahlenkamp
# Dahlenkehre
# Dahlgrünring
# Dahlienweg
# Dahmeweg
# Dahrendorfweg
# Daimlerstraße
# Daimlertwiete
# Dakarweg
# Dalenstieg
# Dallbregen
# Dallbregenstieg
# Dalmannkai
# Damaschkestraße
# Damerowstwiete
# Damerowsweg
# Dammannweg
# Dammstraße
# Dammtordamm
# Dammtorstraße
# Dammtorwall
# Dammwiesenstraße
# Dampfschiffsweg
# Danckwerthweg
# Dangaster Weg
# Daniel-Bartels-Weg
# Daniel-Frese-Straße
# Daniel-Hinsche-Straße
# Danielsenstieg
# Dankerskamp
# Dannenkamp
# Dannenkoppel
# Dannenrüsch
# Dannerallee
# Dannmeyerstraße
# Danziger Straße
# Dar-es-Salaam-Platz
# Darbovenstieg
# Daseweg
# Dassauweg
# Davidstraße
# Davidstreppe
# De Beern
# De Utspann
# De-Voß-Straße
# Deelböge
# Deelbögenkamp
# Deelwisch
# Deelwischredder
# Deepenbrook
# Deepenbrookkamp
# Deepenbrookweg
# Deepenhorn
# Deepenstöcken
# Deesbarg
# Dehnhaide
# Deichgrafenweg
# Deichhausweg
# Deichstraße
# Deichtorplatz
# Deichtorstraße
# Deichtortunnel
# Deichvogt-Peters-Straße
# Deimeweg
# Del-Banco-Kehre
# Delingsdorfer Weg
# Deliusweg
# Delle
# Dellestraße
# Dellingerweg
# Dempwolffstraße
# Denickestraße
# Denksteinweg
# Dennerstraße
# Depenau
# Depenkamp
# Depenwisch
# Derbyweg
# Dernauer Straße
# Desenißstraße
# Dessauer Straße
# Dethlefstwiete
# Detlev-Bremer-Straße
# Detmerstraße
# Diagonalstraße
# Dianaweg
# Dickichtweg
# Diebeskuhle
# Diebsteichbrücke
# Diebsteichweg
# Dieckmühlenweg
# Diedenhofer Straße
# Diekbarg
# Diekdamm
# Diekkamp
# Diekkoppel
# Diekmoorweg
# Diekredder
# Diekweg
# Diekwisch
# Dienerreihe
# Dierksstegel
# Dierksstraße
# Dieselgarten
# Dieselstraße
# Diestelstraße
# Diesterwegstraße
# Dietrich-Schreyge-Straße
# Dietzweg
# Dillstraße
# Dimpfelweg
# Dinkelkamp
# Dirks-Paulun-Weg
# Distelacker
# Distelfalterweg
# Distelkoppel
# Distelweg
# Dithmarscher Straße
# Ditmar-Koel-Straße
# Djakartaweg
# Dobbelersweg
# Dobenplatz
# Dobenstück
# Doberaner Weg
# Dockenhudener Straße
# Doerriesweg
# Doggerbankweg
# Dohlenhorst
# Dohlenweg
# Dohnányiweg
# Dohrnweg
# Doktorberg
# Domenica-Niehoff-Twiete
# Dominikweg
# Dompfaffenweg
# Domstraße
# Domänenweg
# Donauweg
# Donnerstraße
# Doormannsweg
# Doppheide
# Doraustieg
# Dorchgang
# Dorfanger
# Dorferbogen
# Dorferweg
# Dorfgang
# Dorfgrund
# Dorfkoppel
# Dorflageweg
# Dorfstieg
# Dorfstücken
# Dorfwinkel
# Dormienstraße
# Dornbusch
# Dornenkamp
# Dornröschenweg
# Dornstücken
# Dornstückenweg
# Dorothea-Bernstein-Weg
# Dorothea-Gartmann-Straße
# Dorothea-Kasten-Straße
# Dorotheenstraße
# Dorpsfelde
# Dortmunder Straße
# Dosestraße
# Dosseweg
# Dotzauerweg
# Dovenfleet
# Doverkamp
# Drachenstieg
# Dradenaubrücke
# Dradenauer Deichweg
# Dradenaustraße
# Dragonerstall
# Dramburger Weg
# Dratelnstraße
# Drehbahn
# Dreieck
# Dreieckskoppel
# Dreieichenweg
# Dreistücken
# Drevesweg
# Drewer Hauptdeich
# Dreyerpfad
# Drieschweg
# Driftredder
# Driftstieg
# Driftstücken
# Dringsheide
# Dritte Meile
# Dritte Twiete
# Droopweg
# Drosselbartweg
# Drosselstieg
# Drosselstraße
# Droste-Hülshoff-Straße
# Droysenstraße
# Druckerstraße
# Drögenkamp
# Drögensee
# Drögestraße
# Dröögsiet
# Dubben
# Dubbenwinkel
# Dudenweg
# Duderstädter Weg
# Duisburger Straße
# Dulsberg-Nord
# Dulsberg-Süd
# Dunckersweg
# Durchdeich
# Durchschnitt
# Dursun-Akçam-Ufer
# Duschweg
# Dusiplatz
# Duvenacker
# Duvenstedter Berg
# Duvenstedter Damm
# Duvenstedter Markt
# Duvenstedter Triftweg
# Duvenwischen
# Duwockskamp
# Dwarspriel
# Dwarstwiet
# Dwasweg
# Dweerblöcken
# Dweerlandweg
# Dweermoor
# Dwengerkamp
# Dänenweg
# Däumlingtwiete
# Döhnerstraße
# Döhrnstraße
# Döhrntwiete
# Döringweg
# Dörpfeldstieg
# Dörpfeldstraße
# Dörpkamp
# Dörpsweg
# Döscherstraße
# Dünenweg
# Düngelskamp
# Düpenautal
# Düpheid
# Düppelstraße
# Düpweg
# Dürenackersweg
# Dürerstraße
# Düstere Kuhlen
# Düsternstraße
# Düsterntwiete
# Ebeersreye
# Ebeersweg
# Ebelingplatz
# Ebelingstraße
# Ebereschenweg
# Eberhardstraße
# Eberhofstieg
# Eberhofweg
# Eberkamp
# Ebersmoorweg
# Ebersteinweg
# Ebertallee
# Ebner-Eschenbach-Weg
# Eckenerstraße
# Eckerkamp
# Eckerkoppel
# Eckermannstraße
# Eckernförder Straße
# Eckernwoort
# Eckerwiese
# Eckhoffplatz
# Eckloßberg
# Eckmannsweg
# Eckweg
# Eddelbüttelkamp
# Eddelbüttelstraße
# Edelheide
# Edelweißweg
# Edgar-Engelhard-Kai
# Edgar-Roß-Straße
# Edith-Stein-Platz
# Edmund-Siemers-Allee
# Eduard-Duckesz-Straße
# Eduard-F.-Pulvermann-Weg
# Eduard-Reichenbaum-Weg
# Eduard-Rhein-Ufer
# Eduardstraße
# Edvard-Munch-Straße
# Edwin-Scharff-Ring
# Eekbalken
# Eekbalkenstieg
# Eekboomkoppel
# Eekbusch
# Eekholtesweg
# Eenstock
# Efeuweg
# Efftingestraße
# Egenbüttler Weg
# Eggersallee
# Eggerskamp
# Eggersstraße
# Eggerstedtstraße
# Eggersweide
# Eggertweg
# Egilskamp
# Ehestorfer Heuweg
# Ehestorfer Weg
# Ehrenbergstraße
# Ehrenpreisstieg
# Ehrenstieg
# Eibenkamp
# Eibenweg
# Eichberg
# Eichelhäherkamp
# Eichelhäherstieg
# Eichenallee
# Eichenallee (Straße im Bereich Friedhof Ohlsdorf keine amtl. Benennung!)
# Eichendorffstraße
# Eichengrund
# Eichenhag
# Eichenhorst
# Eichenhöhe
# Eichenkamp
# Eichenknick
# Eichenkoppel
# Eichenlohweg
# Eichenredder
# Eichenstraße
# Eichenweg
# Eichheister
# Eichholz
# Eichholzfelder Deich
# Eichstück
# Eichtalstraße
# Eichwischen
# Eickhoffweg
# Eidechsenstieg
# Eidelstedter Brook
# Eidelstedter Dorfstraße
# Eidelstedter Platz
# Eidelstedter Weg
# Eiderstraße
# Eidigweg
# Eierstieg
# Eiffestraße
# Eifflerstraße
# Eigenheimweg
# Eilbeker Bürgerpark
# Eilbeker Weg
# Eilbektal
# Eilenau
# Eilersweg
# Eilswiese
# Eimerskamp
# Eimsbütteler Chaussee
# Eimsbütteler Marktplatz
# Eimsbütteler Straße
# Einhausring
# Einlagedeich
# Einsiedeldeich
# Eisenhansweg
# Eisenkrautweg
# Eisenlohrsweg
# Eishövel
# Eismeerweg
# Eitnerweg
# Eitzensweg
# Eißendorfer Grenzweg
# Eißendorfer Mühlenweg
# Eißendorfer Pferdeweg
# Eißendorfer Straße
# Eißendorfer Waldweg
# Eißendorfer Winkel
# Ekelshofweg
# Ekenkamp
# Ekenknick
# Ekhofstraße
# Elbarkaden
# Elbberg
# Elbblöcken
# Elbchaussee
# Elbgang
# Elbgarten
# Elbgaustraße
# Elbhöhe
# Elbinger Kehre
# Elbkamp
# Elbschlosstreppe
# Elbschloßstraße
# Elbterrasse
# Elbtorpromenade
# Elbtreppe
# Elbuferweg
# Elchweg
# Elebeken
# Eleonorenweg
# Elersring
# Elersstieg
# Elersweg
# Elfenbeinweg
# Elfenwiese
# Elfriede-Land-Weg
# Elfriede-Lohse-Wächtler-Weg
# Elfriedenweg
# Elfsaal
# Elgenkamp
# Elingiusplatz
# Elisabeth-Flügge-Straße
# Elisabeth-Lange-Weg
# Elisabeth-Seifahrt-Weg
# Elisabeth-Thomann-Weg
# Elisabeth-von-Thadden-Kehre
# Elise-Averdieck-Straße
# Elise-Lensing-Weg
# Elisenstraße
# Ellenbogen
# Ellerauer Weg
# Ellerbeker Moordamm
# Ellerbeker Weg
# Ellerbrookskamp
# Ellerbrookswisch
# Ellerholzbrücke
# Ellerholzdamm
# Ellerholzhöft
# Ellerholzweg
# Ellerhoorn
# Ellerneck
# Ellernholt
# Ellernreihe
# Ellernstieg
# Ellerntorsbrücke
# Ellernweg
# Ellernwinkel
# Elligersweg
# Ellmenreichstraße
# Elly-Heuss-Knapp-Ring
# Elly-See-Straße
# Elmenhorststraße
# Elmtwiete
# Elsa-Bauer-Weg
# Elsa-Brändström-Straße
# Elsastraße
# Else-Rauch-Platz
# Elsterweide
# Elstorfer Ring
# Elsässer Straße
# Elversweg
# Emder Straße
# Emekesweg
# Emil-Andresen-Straße
# Emil-Janßen-Straße
# Emil-Wendt-Park
# Emilie-Günther-Weg
# Emilienstraße
# Emily-Ruete-Platz
# Emkendorfstraße
# Emma-Poel-Straße
# Emmastraße
# Emmi-Ruben-Weg
# Emmy-Beckmann-Weg
# Emmy-Püttjer-Straße
# Enckeplatz
# Enderskehre
# Engelbrechtstieg
# Engelbrechtweg
# Engenhusen
# Engernweg
# Englische Planke
# Entenweg
# Entenwerder
# Entenwerder Stieg
# Entenwerder Straße
# Enzianstraße
# Eppendorfer Baum
# Eppendorfer Landstraße
# Eppendorfer Marktplatz
# Eppendorfer Stieg
# Eppendorfer Weg
# Erbestieg
# Erbsenkamp
# Erdkampsweg
# Erdmannstraße
# Erhard-Dressel-Bogen
# Erich-Hippel-Weg
# Erich-Kästner-Ring
# Erich-Plate-Weg
# Erich-Ziegel-Ring
# Erichstraße
# Ericus
# Ericuspromenade
# Ericusspitze
# Erik-Blumenfeld-Platz
# Erika-Etter-Kehre
# Erika-Krauß-Twiete
# Erika-Mann-Bogen
# Erikastraße
# Erikaweg
# Erlenbruch
# Erlengrund
# Erlenhöhe
# Erlenkamp
# Erlenstraße
# Erlental
# Erlerring
# Ermlandweg
# Erna-Behling-Kehre
# Erna-Mohr-Kehre
# Erna-Stahl-Ring
# Ernastraße
# Ernst-Albers-Straße
# Ernst-August-Deich
# Ernst-August-Stieg
# Ernst-August-Straße
# Ernst-Bergeest-Weg
# Ernst-Cassirer-Park
# Ernst-Cassirer-Weg
# Ernst-Eger-Straße
# Ernst-Finder-Weg
# Ernst-Henning-Straße
# Ernst-Horn-Straße
# Ernst-Kabel-Stieg
# Ernst-Mantius-Straße
# Ernst-Merck-Straße
# Ernst-Mittelbach-Ring
# Ernst-Mittelbach-Stieg
# Ernst-Scherling-Weg
# Ernst-Thälmann-Platz
# Ernst-Tichauer-Weg
# Ernteweg
# Erntingweg
# Erpmannstieg
# Erste Brunnenstraße
# Erwin-König-Weg
# Erwin-Seeler-Park
# Erzbergerstraße
# Escheburger Weg
# Eschelsweg
# Eschenahornhof
# Eschenallee (Straße im Bereich Friedhof Ohlsdorf keine amtl. Benennung!)
# Eschenbrook
# Eschenhofbrücke
# Eschenhofplatz
# Eschenhofweg
# Eschenholt
# Eschenstieg
# Eschenweg
# Esmarchstraße
# Espellohweg
# Espenreihe
# Esplanade
# Essener Bogen
# Essener Straße
# Estebogen
# Estedeich
# Etzer Weg
# Etzestraße
# Euckenstraße
# Eulenacker
# Eulenhorst
# Eulenkamp
# Eulenkampweg
# Eulenkrugpfad
# Eulenkrugstraße
# Eulenstraße
# Eulerweg
# Eupener Stieg
# Eupener Straße
# Europabrücke
# Europakai
# Eutiner Straße
# Eva-Hesse-Park
# Eva-König-Bogen
# Eva-Rühmkorf-Straße
# Evastraße
# Everlingweg
# Eversween
# Ewaldsweg
# Ewerstieg
# Eydtkuhnenweg
# Faaßweg
# Faberstraße
# Fabriciusstieg
# Fabriciusstraße
# Fahrenkamp
# Fahrenkrön
# Fahrenkrönstieg
# Fahrenort
# Falbenweg
# Falckweg
# Falenbek
# Falkenbergsweg
# Falkenburger Ring
# Falkenhorst
# Falkenried
# Falkenschlucht
# Falkenstein
# Falkensteiner Ufer
# Falkensteiner Weg
# Falkentaler Weg
# Falkenweg
# Falladabogen
# Fallreep
# Fallstraße
# Fangdieckstraße
# Fanny-David-Weg
# Fanny-Elßler-Bogen
# Fanny-Lewald-Ring
# Fanny-Mendelssohn-Platz
# Farenkoppel
# Farenlandstieg
# Farkenwisch
# Farmsener Höhe
# Farmsener Landstraße
# Farmsener Weg
# Farmsener Zoll
# Farnhornstieg
# Farnhornweg
# Farnstieg
# Farnstraße
# Farnweg
# Fasanengrund
# Fasanenhain
# Fasanenstieg
# Fasanenweg
# Fassbinderweg
# Fattsbarg
# Faßbahn
# Feddersenstraße
# Feekstreek
# Fehlandtstraße
# Fehlinghöhe
# Fehmarnstraße
# Fehnweg
# Fehrsweg
# Fehsenfeldstraße
# Feilenhauerweg
# Feiningerstraße
# Feldahornweg
# Feldblick
# Feldblumenweg
# Feldbrunnenstraße
# Feldhofe
# Feldhoopstücken
# Feldkamp
# Feldlerchenweg
# Feldnerstraße
# Feldrain
# Feldrosenweg
# Feldschmiede
# Feldstegel
# Feldstraße
# Feldweg 21
# Feldweg 31
# Feldweg 50
# Feldweg 55
# Feldweg 60
# Feldweg 62
# Feldweg 63
# Feldweg 64
# Feldweg 65
# Feldweg 67
# Feldweg 69
# Feldweg 70
# Feldweg 72
# Feldweg 77
# Feldweg 78
# Feldweg 79
# Feldweg 81
# Feldweg 82
# Feldweg 83
# Feldweg 84
# Feldweg 85
# Feldweg 88
# Feldweg 90
# Feldweg 91
# Feldweg 92
# Felginerweg
# Felicitas-Kukuck-Straße
# Felix-Dahn-Straße
# Felix-Jud-Ring
# Femerlingstraße
# Fenglerstraße
# Ferdinand-Ancker-Straße
# Ferdinand-Beit-Straße
# Ferdinands Höh
# Ferdinandstor
# Ferdinandstraße
# Fernando-Lorenzen-Platz
# Fernblick
# Ferner Kamp
# Fernsicht
# Fersenfeldtsweg
# Fersenweg
# Fetrasweg
# Fettstraße
# Feuchtheide
# Feuerbachstraße
# Feuerberg
# Feuerbergstraße
# Feuerteichweg
# Feßlerstraße
# Fibigerstraße
# Fichtenkamp
# Fichtenweg
# Fichtestraße
# Fiddigshagen
# Fieberkleestieg
# Fiefstücken
# Fierabendgang
# Fiersbarg
# Fiersbargstieg
# Fingerhutweg
# Finkenau
# Finkenfurth
# Finkenriek
# Finkenrieker Deichweg
# Finkenrieker Hauptdeich
# Finkenschlag
# Finkenstieg
# Finkenstraße
# Finkenwerder Brücke
# Finkenwerder Landscheideweg
# Finkenwerder Norderdeich
# Finkenwerder Ring
# Finkenwerder Ringbrücke-Ost
# Finkenwerder Ringbrücke-Süd
# Finkenwerder Ringbrücke-West
# Finkenwerder Straße
# Finkenwerder Süderdeich
# Finkenwerder Weg
# Finkenwerder Westerdeich
# Finksweg
# Finnmarkring
# Fischadlerstieg
# Fischbeker Heideweg
# Fischbeker Heuweg
# Fischbeker Holtweg
# Fischbeker Moor
# Fischbeker Weg
# Fischbeker Winkel
# Fischbektal
# Fischers Allee
# Fischkamp
# Fischmarkt
# Fischotterstieg
# Fiskalische Straße
# Fitgerweg
# Flachsland
# Flagentwiet
# Flamingoweg
# Flashoffs Treppe
# Flatterbinsenweg
# Flaßbarg
# Flaßheide
# Flaßmoor
# Flaßweg
# Flebbestraße
# Fleestedter Straße
# Fleetdamm
# Fleetplatz
# Flemingstraße
# Flensburger Straße
# Flerrenkamp
# Flerrentwiete
# Flethmannskamp
# Flett
# Fliederweg
# Floot
# Flora-Neumann-Straße
# Florapark
# Flotowstraße
# Flottbeker Drift
# Flottbeker Marktweg
# Flottbeker Stieg
# Flottbektal
# Flughafenstraße
# Flurkamp
# Flurstraße
# Flutende
# Flüggenhofstieg
# Flüggestraße
# Flünkentwiete
# Fockenweide
# Focksweg
# Fohlenweide
# Fohrwisch
# Fontanestraße
# Fontenay
# Fontenay-Allee
# Foorthkamp
# Foortstegel
# Forbacher Straße
# Forsmannstraße
# Forsteck
# Forstgrund
# Forsthöhe
# Forstweg
# Foßberger Moor
# Foßholt
# Foßredder
# Foßsölen
# Fraenkelstraße
# Frahmredder
# Frahmstraße
# Framheinstraße
# Francoper Hinterdeich
# Francoper Straße
# Frankenstraße
# Frankring
# Franz-Gartmann-Treppe
# Franz-Marc-Straße
# Franz-Rohr-Weg
# Franz-Röttel-Park
# Franzosenheide
# Franzosenkoppel
# Frapanweg
# Frascatiplatz
# Frauenthal
# Freegen
# Freegenweg
# Freesenstraße
# Freesienweg
# Freihafenelbbrücke
# Freihafenstraße
# Freiligrathstraße
# Freiweide
# Frettchenweg
# Freudenthalweg
# Frickestraße
# Frieda-Wieking-Stieg
# Friedastraße
# Friedensallee
# Friedenstraße
# Friedensweg
# Friederike-Büscher-Wanderweg
# Friederike-Klünder-Weg
# Friedhofstraße
# Friedhofsweg
# Friedländer Straße
# Friedmannbogen
# Friedrich-Ebert-Damm
# Friedrich-Ebert-Hof
# Friedrich-Ebert-Straße
# Friedrich-Frank-Bogen
# Friedrich-Karl-Straße
# Friedrich-Kirsten-Straße
# Friedrich-Legahn-Straße
# Friedrich-List-Straße
# Friedrich-Ludwig-Jahn-Straße
# Friedrich-Naumann-Straße
# Friedrich-Schöning-Weg
# Friedrich-Schütter-Platz
# Friedrichsberger Park
# Friedrichsberger Straße
# Friedrichshainstraße
# Friedrichshulder Weg
# Friedrichstraße
# Friesenstraße
# Friesenweg
# Fritz-Bringmann-Ring
# Fritz-Döhling-Weg
# Fritz-Flinte-Ring
# Fritz-Lindemann-Weg
# Fritz-Manke-Weg
# Fritz-Neubers-Weg
# Fritz-Reuter-Straße
# Fritz-Schade-Weg
# Fritz-Schumacher-Allee
# Fritz-Solmitz-Weg
# Fritz-Stoffert-Straße
# Fritzschweg
# Frobeniusweg
# Frohbösestraße
# Frohmestraße
# Froschkönigweg
# Fruchtallee
# Fruchtweg
# Frustbergstraße
# Fruteweg
# Fröbelstraße
# Frühlingsgarten
# Frühlingsheide
# Frühlingstraße
# Fuchsbergredder
# Fuchsbergweg
# Fuchsienweg
# Fuchsloch
# Fuchsversteck
# Fuchswechsel
# Fuhlendorfweg
# Fuhlentwiete
# Fuhlsbütteler Damm
# Fuhlsbütteler Weg
# Fuhlsbüttler Passage
# Fuhlsbüttler Straße
# Fuhrenkamp
# Fuldastieg
# Funhofweg
# Funkstraße
# Furchenacker
# Furtredder
# Furtstieg
# Furtweg
# Fährdamm
# Fährhausbrücke
# Fährhausstraße
# Fährkrogweg
# Fährstieg
# Fährstraße
# Föhrenheide
# Föhrenholt
# Föhrenholtweg
# Föhrenweg
# Försterkamp
# Försterstieg
# Försterweg
# Föttingergarten
# Füerbarg
# Fünfhausener Deichweg
# Fünfhausener Hauptdeich
# Fünfhausener Landweg
# Fünfhausener Straße
# Fünfstück
# Fürstendahlen
# Fürstenmoordamm
# GST-Routen Ergänzung in Niedersachsen
# Gademannstraße
# Gaedechensweg
# Gagelstrauchweg
# Gaiserstraße
# Galileiweg
# Gammer Weg
# Gandersheimer Weg
# Gannerbarg
# Garbersweg
# Garbestraße
# Gardinger Weg
# Garleff-Bindt-Weg
# Garlstorfer Stieg
# Garnstück
# Garrelsweg
# Garstedter Eck
# Garstedter Weg
# Gartenfrieden
# Gartenstadtweg
# Gasstraße
# Gastkamp
# Gaswerkweg
# Gauerter Hauptdeich
# Gaußstraße
# Gayens Weg
# Gazellenkamp
# Gazertstraße
# Gebrüder-Cohen-Park
# Gebrüder-Wolf-Platz
# Gebweiler Straße
# Geerzkamp
# Geesmoor
# Geesthachter Kehre
# Geesthachter Weg
# Geesthang
# Geesttwiete
# Geffckenstraße
# Gefionstraße
# Gehegekamp
# Gehegestieg
# Gehegewinkel
# Gehlengraben
# Gehlenkamp
# Gehrdenweg
# Gehrkensweg
# Gehölzweg
# Geibelstraße
# Geibweg
# Geidelberg
# Geierstraße
# Geißleinweg
# Geißlertwiete
# Gellersenweg
# Gellertstraße
# Gemeinweide
# Gemseneck
# Genslerstraße
# Genter Ufer
# Georg-Appel-Straße
# Georg-Blume-Straße
# Georg-Bonne-Straße
# Georg-Clasen-Weg
# Georg-Heyken-Straße
# Georg-Raloff-Ring
# Georg-Thielen-Gasse
# Georg-Wilhelm-Straße
# Georges-André-Kohn-Straße
# Georginenweg
# Georgiweg
# Georgsplatz
# Georgstraße
# Georgswerder Bogen
# Georgswerder Damm
# Georgswerder Ring
# Gepidenweg
# Gerade Straße
# Geraer Weg
# Geranienweg
# Gerberstraße
# Gerckensplatz
# Gerda-Gmelin-Platz
# Gerdauring
# Gerhard-Falk-Straße
# Gerhardstraße
# Gerhart-Hauptmann-Platz
# Gerhofstraße
# Gerichtstraße
# Gerlachstraße
# Gerlindweg
# Germanenweg
# Germerring
# Gernotstraße
# Gernroder Weg
# Gerntkebogen
# Geroweg
# Gerritstraße
# Gersonweg
# Gerstenbergstraße
# Gerstenkamp
# Gerstenkoppel
# Gerstenwiese
# Gerstäckerstraße
# Gert-Marcus-Straße
# Gert-Schwämmle-Weg
# Gertigstraße
# Gertrud-Bäumer-Stieg
# Gertrud-Meyer-Straße
# Gertrud-Pardo-Weg
# Gertrud-Seele-Kehre
# Gertrud-Werner-Weg
# Gertrud-von-Thaden-Platz
# Gertrudenkirchhof
# Gertrudenstraße
# Geschwister-Beschütz-Bogen
# Geschwister-Scholl-Straße
# Geschwister-Witonski-Straße
# Geutensweg
# Gewerbeschulweg
# Gewerkschaftsweg
# Giesestraße
# Giffeyweg
# Gilbertstraße
# Gilcherweg
# Gildering
# Gilgegrund
# Gimpelweg
# Ginsterheide
# Ginsterstieg
# Giselaweg
# Glacischaussee
# Gladiolenweg
# Gladowstraße
# Glaeßweg
# Glasbergstraße
# Glasbläserhöfe
# Glashüttenstraße
# Glashütter Landstraße
# Glashütter Stieg
# Glatzer Straße
# Gleisstieg
# Gleiwitzer Bogen
# Glinder Straße
# Glindersweg
# Glindkamp
# Glindweg
# Glindwiese
# Glitzaweg
# Glißmannweg
# Glockenblumenweg
# Glockengießerwall
# Glockenhausbrücke
# Glockenheide
# Glogauer Straße
# Gloxinienweg
# Gluckstraße
# Glückel-von-Hameln-Straße
# Glücksburger Straße
# Glückstädter Weg
# Gnadenbergweg
# Gneisenaustraße
# Gockelstieg
# Godeffroystraße
# Godenwind
# Goebenstraße
# Goerdelerstraße
# Goernestraße
# Goeschenstraße
# Goetheallee
# Goetheplatz
# Goethestraße
# Goetjensorter Deich
# Gojenbergsweg
# Goldammerweg
# Goldaper Kehre
# Goldbachstraße
# Goldbekplatz
# Goldbekufer
# Goldbekweg
# Golddistelweg
# Goldelsestieg
# Goldene Wiege
# Goldhähnchenstieg
# Goldkoppel
# Goldkäferweg
# Goldlackweg
# Goldmariekenweg
# Goldnesselweg
# Goldparmänenweg
# Goldregenweg
# Goldrutenweg
# Goldröschenweg
# Goldtschmidtstraße
# Golfstraße
# Goosacker
# Goppeltweg
# Gorch-Fock-Park
# Gorch-Fock-Straße
# Gorch-Fock-Wall
# Gordonkehre
# Gordonstraße
# Gosepfad
# Goslarer Weg
# Gotenstraße
# Gotenweg
# Gothaer Weg
# Gottfried-Keller-Straße
# Gotthelfweg
# Gottorpstraße
# Gottschalkring
# Gottschalkweg
# Gottschedstraße
# Govertsweg
# Goßlers Park
# Goßlerstraße
# Grabauer Weg
# Grabbestraße
# Grabendamm
# Grabenstieg
# Grabenstraße
# Grabenstücken
# Grabkeweg
# Grachtenplatz
# Graf-Anton-Weg
# Graf-Ernst-Weg
# Graf-Johann-Weg
# Graf-Otto-Weg
# Gramkowweg
# Grandeswerder Straße
# Grandkoppel
# Grandkoppelstieg
# Grandkuhlenweg
# Grandweg
# Granitweg
# Grasbrookpark
# Grashofweg
# Graskeller
# Grasmoor
# Grasnelkenweg
# Grasredder
# Grasweg
# Graudenzer Weg
# Graumannsweg
# Graumanntwiete
# Graustraße
# Gravensteiner Straße
# Gravensteiner Weg
# Graßmannweg
# Greflingerstraße
# Greifenberger Straße
# Greifenhagener Straße
# Greifswalder Straße
# Grelckstraße
# Grellkamp
# Grellkampkehre
# Grellkampstieg
# Grenzacker
# Grenzbachstraße
# Grenzkehre
# Grenzknick
# Grenzwisch
# Gretchen-Wohlwill-Platz
# Gretchenkoppel
# Grete-Nevermann-Weg
# Grete-Zabe-Weg
# Gretelstieg
# Grevenau
# Grevenhofkai
# Grevenweg
# Greves Garten
# Griegstraße
# Griesstraße
# Grillenweg
# Grillparzerstraße
# Grimm
# Grimmstraße
# Grindelallee
# Grindelberg
# Grindelhof
# Grindelweg
# Gromballring
# Groot Enn
# Groote Wischen
# Groothoffgasse
# Grootmoor
# Grootmoorgraben
# Grootmoorredder
# Grootmoortwiete
# Grootmoorweg
# Grootsruhe
# Gropiusring
# Grosseweg
# Grot Sahl
# Grote Koppel
# Grote Raak
# Grote Stegel
# Grote String
# Grotefendweg
# Grotelertreppe
# Grotelertwiete
# Grotelerweg
# Groten Flerren
# Groten Heesen
# Groten Hoff
# Grotenbleken
# Grotenkamp
# Grotestraße
# Grothwisch
# Grotiusweg
# Grotjahnstraße
# Grotkoppelweg
# Grotmannskroog
# Grottenstraße
# Grovestraße
# Groß Borsteler Straße
# Groß Flottbeker Straße
# Groß-Sand
# Große Bahnstraße
# Große Bergstraße
# Große Bleichen
# Große Brunnenstraße
# Große Bäckerstraße
# Große Elbstraße
# Große Freiheit
# Große Holl
# Große Horst
# Große Johannisstraße
# Große Rainstraße
# Große Reichenstraße
# Große Straße
# Große Theaterstraße
# Große Wallanlagen
# Große Wiese
# Großer Burstah
# Großer Grasbrook
# Großer Ring
# Großer Schippsee
# Großer Stackort
# Großer Trampgang
# Großheidesteg
# Großheidestraße
# Großlohering
# Großmannstraße
# Großmoorbogen
# Großmoordamm
# Großmoorkehre
# Großmoorring
# Großneumarkt
# Grube
# Grubenstieg
# Grubesallee
# Grumbrechtstraße
# Grundheide
# Grundherrenstraße
# Grundstraße
# Grunewaldstraße
# Grusonstraße
# Grusort
# Grusortwinkel
# Gryphiusstraße
# Grädenerstraße
# Gräningstieg
# Gräpelweg
# Grögersweg
# Grömitzer Weg
# Grönenweg
# Grönkamp
# Grönlander Damm
# Gründgensstraße
# Grünebergstraße
# Grüner Deich
# Grüner Redder
# Grüner Weg
# Grüner Winkel
# Grünewaldstraße
# Grüningweg
# Grünspechtweg
# Grützmühlenweg
# Gubener Straße
# Guderuper Straße
# Gudrunstraße
# Guerickeweg
# Guldtweg
# Gumbinner Kehre
# Gundermannstraße
# Gundlachs Twiete
# Gurlittstraße
# Gussau
# Gustav-Adolf-Straße
# Gustav-Falke-Straße
# Gustav-Freytag-Straße
# Gustav-Klimt-Weg
# Gustav-Kunst-Straße
# Gustav-Leo-Straße
# Gustav-Mahler-Park
# Gustav-Mahler-Platz
# Gustav-Schwab-Straße
# Gustav-Seitz-Weg
# Gustav-Weihrauch-Weg
# Gustavsweg
# Gutenbergstraße
# Gutsmuthsweg
# Gutswisch
# Guttmannring
# Gutzkowstraße
# Gyula-Trebitsch-Platz
# Gählerstraße
# Gänselieselweg
# Gänsemarkt
# Gänsestieg
# Gärtnerstraße
# Gärtnerweg
# Gätgensstraße
# Gödeke-Michels-Weg
# Gödersenweg
# Göhlbachtal
# Göhslerstieg
# Görlitzer Straße
# Görresring
# Görttwiete
# Gösselkoppel
# Gösselweide
# Götkensweg
# Götzberger Weg
# Güllweg
# Günselstieg
# Günter-Püstow-Straße
# Günther-Schwarberg-Weg
# Güntherstraße
# Günzweg
# Güstrower Weg
# Haakestraße
# Haanbalken
# Haberkamp
# Habermannstraße
# Habichthorst
# Habichtshofring
# Habichtsplatz
# Habichtstraße
# Habichtsweg
# Habigerstieg
# Hachmannkai
# Hachmannplatz
# Hackmackbogen
# Hadermanns Weg
# Haderslebener Straße
# Hadubrandheide
# Haeckelstraße
# Haeckswisch
# Haempten
# Hafenbezirk
# Hafenrandstraße
# Hafentor
# Hafentreppe
# Haferacker
# Haferblöcken
# Haferkamp
# Haferstück
# Haferweg
# Haffkruger Weg
# Hagebuttenweg
# Hagebökenholt
# Hagedornstraße
# Hagenau
# Hagenbeckallee
# Hagenbeckstraße
# Hagendeel
# Hagenende
# Hagenower Straße
# Hagenweg
# Hahnemannstraße
# Hahnenfußweg
# Hahnenkamp
# Hahntrapp
# Haidlandsring
# Haidlandstieg
# Haidlandsweg
# Hainbuchenallee
# Hainbuchenweg
# Haindaalwisch
# Hainholz
# Hainholzfeld
# Hainholzweg
# Hainveilchenplatz
# Haithabuweg
# Hakenstraße
# Halbenkamp
# Halberstädter Weg
# Halbmondsweg
# Haldenstieg
# Haldesdorfer Straße
# Halenreie
# Halenriggen
# Halenseering
# Hallerplatz
# Hallerstraße
# Halligenstieg
# Halskestraße
# Halstenbeker Stieg
# Halstenbeker Straße
# Halstenbeker Weg
# Hamborner Stieg
# Hamburger Berg
# Hamburger Hochstraße
# Hamburger Straße
# Hamelausweg
# Hammenmacherstieg
# Hammer Baum
# Hammer Berg
# Hammer Deich
# Hammer Hof
# Hammer Landstraße
# Hammer Steindamm
# Hammer Straße
# Hammer Weg
# Hammerbrookstraße
# Hammerichstraße
# Hamraakoppel
# Handelmannweg
# Handweg
# Hanfftsweg
# Hanfstieg
# Hangheide
# Hangstraße
# Hangtwiete
# Hanhoopsfeld
# Hanne-Darboven-Ring
# Hanne-Mertens-Weg
# Hannenstieg
# Hannenstücken
# Hannoversche Straße
# Hans-Adolf-Weg
# Hans-Albers-Platz
# Hans-Christian-Andersen-Park
# Hans-Dewitz-Ring
# Hans-Duncker-Straße
# Hans-Fitze-Straße
# Hans-Freese-Weg
# Hans-Förster-Bogen
# Hans-Grahl-Weg
# Hans-Henny-Jahnn-Weg
# Hans-Hinnik-Weg
# Hans-Lange-Straße
# Hans-Leip-Ufer
# Hans-Mahler-Straße
# Hans-Matthiessen-Straße
# Hans-Much-Weg
# Hans-Rubbert-Straße
# Hans-Sachs-Straße
# Hans-Sander-Straße
# Hans-Stoll-Straße
# Hans-Thoma-Weg
# Hans-Ulrich-Höller-Weg
# Hansahöft
# Hansaplatz
# Hansastraße
# Hansdorfer Straße
# Hanseatenstieg
# Hanseatenweg
# Hansingweg
# Hanssensweg
# Hanstedter Stieg
# Harald-Stender-Platz
# Harburger Chaussee
# Harburger Hafenschleuse
# Harburger Hauptdeich
# Harburger Poststraße
# Harburger Rathausforum
# Harburger Rathauspassage
# Harburger Rathausplatz
# Harburger Rathausstraße
# Harburger Ring
# Harburger Schloßstraße
# Hardauring
# Hardenbergstraße
# Hardenstraße
# Harders Kamp
# Harderweg
# Hardorffsweg
# Harkensee
# Harkenseepark
# Harkortstieg
# Harkortstraße
# Harksheider Straße
# Harmsenstraße
# Harmsstraße
# Harmsweg
# Harnackring
# Harnacksweg
# Harnisch
# Harry-Hartz-Weg
# Hartje-Rüter-Weg
# Hartkrögen
# Hartmannsau
# Hartmutkoppel
# Hartnitweg
# Hartsprung
# Hartungstraße
# Hartwicusstraße
# Hartwig-Hesse-Straße
# Hartzloh
# Hartzlohplatz
# Harvestehuder Stieg
# Harvestehuder Weg
# Harzburger Weg
# Harzensweg
# Haselbusch
# Haseldorfer Weg
# Haselhain
# Haselkamp
# Haselknick
# Haselnußweg
# Hasenbanckweg
# Hasenböge
# Hasencleverstraße
# Haseneck
# Hasenheide
# Hasenhoop
# Hasenhöhe
# Hasenstieg
# Hasenweg
# Hasenwinkel
# Hasloher Kehre
# Hasselbrookstraße
# Hasselmannstraße
# Hasselwerder Straße
# Hasselwisch
# Hassestraße
# Hastedtplatz
# Hastedtstraße
# Hastedtweg
# Hatjeweg
# Hattinger Stieg
# Hattsmoor
# Hatzberg
# Haubachstraße
# Haubenlerchenweg
# Haubentaucherweg
# Hauersweg
# Hauffstraße
# Hauke-Haien-Weg
# Hauland
# Haulander Hauptdeich
# Haulander Weg
# Hausbrucher Bahnhofstraße
# Hausbrucher Eck
# Hausbrucher Kehre
# Hausbrucher Moor
# Hausbrucher Straße
# Hauskoppel
# Hauskoppelstieg
# Hauwisch
# Havermannstieg
# Havighorster Redder
# Havighorster Weg
# Haydnstraße
# Haynstraße
# Haßloredder
# Hebbelstraße
# Hebebrandbrücke
# Hebebrandstraße
# Heckende
# Heckengang
# Heckenpfad
# Heckenrosenweg
# Heckenrund
# Heckenstieg
# Heckkatenweg
# Heckkoppel
# Heckscherstraße
# Hederichweg
# Heegbarg
# Heerbrook
# Heerbuckhoop
# Heerhof
# Heerwegbrücke
# Heerwisch
# Heeskoppel
# Heestweg
# Hegarstraße
# Hegelingenstieg
# Hegeneck
# Hegenredder
# Hegereiterweg
# Hegestieg
# Hegestraße
# Hegholt
# Hegtum
# Heidacker
# Heidberg
# Heidbergredder
# Heidblick
# Heiddiek
# Heideblöck
# Heideblütenweg
# Heidebrinker Weg
# Heidebruch
# Heidegängerweg
# Heideknick
# Heidekrautweg
# Heidelerchenweg
# Heidelibellenweg
# Heidemoor
# Heidenhorstweg
# Heidenkampsweg
# Heider Straße
# Heiderosenweg
# Heideweg
# Heidewinkel
# Heidewisch
# Heidhofsweg
# Heidhorst
# Heidhorststieg
# Heidhörn
# Heidi-Kabel-Platz
# Heidjerweg
# Heidkamp
# Heidkampsredder
# Heidkoppel
# Heidkrug
# Heidland
# Heidloge
# Heidlohstraße
# Heidrand
# Heidredder
# Heidrehmen
# Heidritterstraße
# Heidschnuckenring
# Heidstücken
# Heidstückenkehre
# Heidstückenweg
# Heilholtkamp
# Heiligengeistbrücke
# ...
# Strohblumenweg
# Strohredder
# Struckholt
# Struckholttwiete
# Strucksbarg
# Struenseestraße
# Strutzhang
# Strübelhorn
# Strüverweg
# Stubbenberg
# Stubbenhof
# Stubbenhuk
# Stubbenweg
# Studioweg
# Stuhlmannplatz
# Stuhlmannstraße
# Stuhlrohrstraße
# Stuhtsweg
# Sturmvogelweg
# Stutsmoor
# Stutzenkamp
# Stuvkamp
# Stölckenhofwinkel
# Störtebeker Ufer
# Störtebekerweg
# Stöttrupweg
# Stübeheide
# Stübekamp
# Stübenhofer Weg
# Stübenplatz
# Stüberedder
# Stückenstraße
# Stückweg
# Stüfelkoppel
# Stüffel
# Stüffeleck
# Stüffeloort
# Stüffelring
# Stühmtwiete
# Suckweg
# Sudeckstraße
# Sudermannstraße
# Sudestraße
# Suerfeld
# Sugambrerweg
# Suhmweg
# Suhrenkamp
# Suhrsweg
# Sulkyweg
# Sultanstraße
# Sumpfcallastieg
# Sumpfläuferweg
# Sumpfmeisenweg
# Sumpfveilchenweg
# Sumpfweg
# Sunderweg
# Surenland
# Susanne-von-Paczensky-Straße
# Susannenstraße
# Susebekweg
# Susettestraße
# Suttnerstraße
# Suurbleek
# Suurheid
# Suurwisch
# Sven-Hedin-Straße
# Swartenhorst
# Swatten Weg
# Swebenbrunnen
# Swebengrund
# Swebenhöhe
# Swebenweg
# Swinemünder Straße
# Sydneystraße
# Sylter Weg
# Sylvesterallee
# Syringenweg
# Sägemühlenstraße
# Söbendieken
# Söderblomstraße
# Sörensenweg
# Südallee (Straße im Bereich Friedhof Ohlsdorf keine amtl. Benennung!)
# Süder-Ohe
# Süderelbebogen
# Süderelbering
# Süderelbeweg
# Süderfeldstraße
# Süderkirchenweg
# Süderquerweg
# Süderstraße
# Südheide
# Südring
# Sülfelder Weg
# Süllbergsterrasse
# Süllbergstreppe
# Süllbergsweg
# Sülldorfer Brooksweg
# Sülldorfer Heideweg
# Sülldorfer Kirchenweg
# Sülldorfer Knick
# Sülldorfer Landstraße
# Sülldorfer Mühlenweg
# Sülzbrackring
# Sünnenschien
# Süntelstraße
# Tabulatorweg
# Tafelberg
# Talheide
# Talstraße
# Talstraße (Straße im Bereich Friedhof Ohlsdorf keine amtl. Benennung!)
# Talweg
# Talwinkel
# Tangstedter Graben
# Tangstedter Knick
# Tangstedter Landstraße
# Tangstedter Weg
# Tankweg
# Tanneck
# Tannenberg
# Tannengrünweg
# Tannenhof
# Tannenhügel
# Tannenkamp
# Tannenweg
# Tannenzuschlag
# Tannhäuserweg
# Tarfenbööm
# Tarnowitzer Weg
# Tarpen
# Tarpenbekstraße
# Tarpenring
# Tarpenstieg
# Tarpenwiese
# Tasköprüstraße
# Tatenberger Damm
# Tatenberger Deich
# Tatenberger Weg
# Taubenstraße
# Taubnesselweg
# Tauchnitzweg
# Tausendblattweg
# Taxusweg
# Teekoppel
# Teerhof
# Teerosenweg
# Teetzparkweg
# Tegelsbarg
# Tegelweg
# Tegetthoffstraße
# Teichhuhnstraße
# Teichrosenweg
# Teichstraße (Straße im Bereich Friedhof Ohlsdorf keine amtl. Benennung!)
# Teilfeld
# Teinstücken
# Telemannstraße
# Tellkampfweg
# Tempelhofer Ring
# Tempoweg
# Tempowerkring
# Tennigkeitweg
# Tesdorpfstraße
# Tessenowweg
# Teubnerweg
# Teufelsbrück
# Teutonenweg
# Tewessteg
# Thadenstraße
# Thedestraße
# Theodor-Fahr-Straße
# Theodor-Heuss-Platz
# Theodor-Körner-Weg
# Theodor-Rumpel-Stieg
# Theodor-Rumpel-Weg
# Theodor-Schäfer-Damm
# Theodor-Storm-Straße
# Theodor-Weber-Reihe
# Theodor-Yorck-Straße
# Theodorstieg
# Theodorstraße
# Therese-Giehse-Bogen
# Theresenweg
# Theresienstieg
# Thiedeweg
# Thiedingreihe
# Thielbek
# Thielenstraße
# Thielickestieg
# Thiemannhof
# Thiemannstraße
# Thießenweg
# Thingsberg
# Thomas-Mann-Straße
# Thomasstraße
# Thormannstieg
# Thorner Gasse
# Thuleweg
# Thunstraße
# Thusneldastraße
# Thymianstieg
# Thörlstraße
# Thörlweg
# Thüreystraße
# Thüringerweg
# Tibarg
# Tiecksweg
# Tiedemannstraße
# Tiefenstraße
# Tieloh
# Tienrade
# Tienradestieg
# Tiergartenstraße
# Tierparkallee
# Tietzestraße
# Tigerstraße
# Tilemannhöhe
# Tilsiter Straße
# Timm-Kröger-Weg
# Timmendorfer Stieg
# Timmendorfer Straße
# Timmerloh
# Timmermannsredder
# Timmermannstraße
# Timmermoor
# Timmkoppel
# Timms Hege
# Timmstieg
# Timmweg
# Tinnumer Weg
# Tinsdaler Heideweg
# Tinsdaler Kirchenweg
# Tiroler Straße
# Tischbeinstraße
# Tischendorfweg
# Tivoliweg
# Todtenredder
# Togokai
# Tokiostraße
# Toller Ort
# Tollerortweg
# Tondernstieg
# Tondernstraße
# Tongrubenweg
# Tonistraße
# Tonkuhlenweg
# Tonndorfer Hauptstraße
# Tonndorfer Schulstraße
# Tonndorfer Strand
# Tonndorfer Weg
# Tonradsmoor
# Torfhuder Stieg
# Torfstecherweg
# Torfstück
# Torfweg
# Tornberg
# Tornquiststraße
# Torontobrücke
# Torstraße
# Traberweg
# Trakehner Kehre
# Tralauer Kehre
# Tratzigerstraße
# Trauns Allee
# Traunweg
# Travemünder Stieg
# Travestieg
# Trebelstraße
# Treidelweg
# Trelder Weg
# Trenknerweg
# Treptower Straße
# Tresckowstraße
# Trettaustraße
# Treuburger Weg
# Treudelberg
# Treudelbergkamp
# Treudelbergweg
# Tribünenweg
# Trift
# Triftheide
# Trifthof
# Triftkoppel
# Triftstraße
# Triftweg
# Trillup
# Trilluper Stieg
# Trilluper Weg
# Tristanweg
# Trittauer Amtsweg
# Trollblumenweg
# Trommelstraße
# Tronjeweg
# Troplowitzstraße
# Trostbrücke
# Trummersweg
# Tröndelstieg
# Tröndelwisch
# Trübnerweg
# Tschaikowskyplatz
# Tucholskyring
# Tulpenstieg
# Tunnelstraße
# Tunneltalbrücke
# Tunnkoppelring
# Tunnkoppelstieg
# Turmfalkweg
# Turmweg
# Turnerstraße
# Turnierstieg
# Turonenweg
# Tweeflunken
# Tweeltenbek
# Tweeltenmoor
# Tweestücken
# Twietenknick
# Twietenkoppel
# Twisselwisch
# Twistering
# Tycho-Brahe-Weg
# Tönerweg
# Tönninger Straße
# Tönninger Weg
# Tönns-Wulf-Weg
# Tönsfeldtstraße
# Töpferhof
# Töpferstieg
# Töpfertwiete
# Tückobsmoor
# Ubierweg
# Uckermarkweg
# Ueckerstraße
# Uferstraße
# Uferwindenweg
# Uffelnsweg
# Uhdeweg
# Uhlandstraße
# Uhlenbüttler Kamp
# Uhlenhoffweg
# Uhlenhorster Weg
# Uhuweg
# Ulenflucht
# Ulenlock
# Ulenweg
# Ulferusweg
# Ulmenau
# Ulmenhang
# Ulmenliet
# Ulmenstraße
# Ulzburger Straße
# Undeloher Winkel
# Unnastraße
# Unnenland
# Untenburger Querweg
# Untenburger Stieg
# Unterberg
# Untere Bergkoppel
# Unterelbestraße
# Unterer Landweg
# Unterm Heilbrunnen
# Unzerstraße
# Up de Schanz
# Up de Worth
# Up den Wiemen
# Uphoffweg
# Upn Hornack
# Uppenhof
# Urenfleet
# Urnenfeld
# Urnenhang
# Ursula-Falke-Terrassen
# Ursula-Querner-Straße
# Ursula-de-Boor-Straße
# Usedomstraße
# Uteweg
# Utkiek
# Uwestraße
# VHM-Straße
# Vagel-Griep-Platz
# Vahlenkampffweg
# Vahrendorfer Stadtweg
# Vahrenwinkelweg
# Valentinskamp
# Valparaisostraße
# Van-der-Smissen-Straße
# Vancouverstraße
# Vasco-da-Gama-Platz
# Veddeler Bogen
# Veddeler Brückenstraße
# Veddeler Damm
# Veddeler Elbdeich
# Veddeler Marktplatz
# Veddeler Stieg
# Veddeler Straße
# Veddelhöft
# Veermoor
# Veerstücken
# Vehrenkampstraße
# Veilchenstieg
# Veilchenweg
# Veit-Stoß-Weg
# Veltheimstraße
# Venusberg
# Vera-Brittain-Ufer
# Verbindungsstraße
# Vereinsstraße
# Vereinsweg
# Veringstraße
# Veringweg
# Veritaskai
# Versmannkai
# Versmannstraße
# Victoriaallee
# Victoriakai-Ufer
# Victoriaring
# Vielohkamp
# Vielohweg
# Vielohwisch
# Vienenburger Weg
# Vierbergen
# Vierbergentwiete
# Viereck
# Vierenkamp
# Vierlandenstraße
# Vierländer Brücke
# Vierländer Damm
# Vierte Twiete
# Vierzigstücken
# Vietinghoffweg
# Vinetastraße
# Vinhagenweg
# Vinzenzweg
# Virchowstraße
# Vizelinstraße
# Vogelbeerenweg
# Vogelerstraße
# Vogelhüttenberg
# Vogelhüttendeich
# Vogelreth
# Vogelweide
# Vogesenstraße
# Vogt-Bornkast-Weg
# Vogt-Cordes-Damm
# Vogt-Groth-Weg
# Vogt-Kock-Weg
# Vogt-Kölln-Straße
# Vogt-Wells-Kamp
# Vogt-Wells-Straße
# Vogteistraße
# Vogteiweg
# Vogtredder
# Vogtshof
# Vogtskamp
# Voigtstraße
# Volkerweg
# Volkmannstraße
# Volksdorfer Damm
# Volksdorfer Grenzweg
# Volksdorfer Straße
# Volksdorfer Weg
# Volksparkstieg
# Volksparkstraße
# Volkswohlweg
# Vollhöfner Weiden
# Vollmersweg
# Volzekenweg
# Vom-Berge-Weg
# Von-Anckeln-Straße
# Von-Appen-Straße
# Von-Axen-Straße
# Von-Bargen-Straße
# Von-Cölln-Weg
# Von-Eicken-Straße
# Von-Elm-Stieg
# Von-Elm-Weg
# Von-Essen-Straße
# Von-Graffen-Straße
# Von-Hacht-Weg
# Von-Haeften-Straße
# Von-Halem-Straße
# Von-Hein-Straße
# Von-Herslo-Weg
# Von-Heß-Weg
# Von-Hutten-Straße
# Von-Kurtzrock-Ring
# Von-Melle-Park
# Von-Moltke-Bogen
# Von-Sauer-Straße
# Von-Scheliha-Straße
# Von-Suppé-Straße
# Von-Thünen-Straße
# Von-der-Tann-Straße
# Vor dem Berge
# Vorbeckweg
# Vorderdeich
# Vorderkamp
# Vorderste Wiese
# Vorhornweg
# Vorlandring
# Vorsetzen
# Vorwerkstraße
# Voßdrift
# Voßhagen
# Voßkamp
# Voßkoppel
# Voßkulen
# Voßort
# Voßstraat
# Voßweg
# Vulkanhöft
# Völckersstraße
# Vörloh
# Vörn Barkholt
# Vörn Brook
# Vörn Styg
# Vörn Voßbarg
# Vörstekoppel
# Wacholderweg
# Wachsbleiche
# Wachstwiete
# Wachtelstraße
# Wachtelthal
# Wackerhagen
# Wackerweg
# Wagenerstieg
# Wagenfeldstraße
# Wagenwerkweg
# Wagnerkoppel
# Wagnerstraße
# Wagrierweg
# Waidmannstraße
# Waisenstieg
# Waitzstraße
# Wakendorfer Weg
# Walddörferstieg
# Walddörferstraße
# Waldenauer Weg
# Waldenburger Straße
# Walderseestraße
# Waldfrieden
# Waldherrenallee
# Waldingstraße
# Waldkehre
# Waldrebenweg
# Waldredder
# Waldreiterring
# Waldschlucht
# Waldstraße (Straße im Bereich Friedhof Ohlsdorf keine amtl. Benennung!)
# Waldteufelweg
# Waldvogteiweg
# Waldvogtstraße
# Waldweg
# Waldwinkel
# Walkmühlenweg
# Wallgraben
# Wallringtunnel
# Wallstraße
# Walnußstieg
# Walsroder Ring
# Walstieg
# Walter-Becker-Straße
# Walter-Bärsch-Weg
# Walter-Dudek-Brücke
# Walter-Flex-Straße
# Walter-Frahm-Stieg
# Walter-Freitag-Straße
# Walter-Hammer-Weg
# Walter-Heitmann-Straße
# Walter-Jungleib-Straße
# Walter-Koch-Weg
# Walter-Koppel-Weg
# Walter-Möller-Park
# Walter-Rothenburg-Weg
# Walter-Rudolphi-Weg
# Walter-Schmedemann-Straße
# Walter-Schüler-Weg
# Walter-Wächter-Platz
# Waltershofer Damm
# Waltershofer Höft
# Waltershofer Straße
# Walther-Kunze-Straße
# Walther-Mahlau-Stieg
# Wandalenweg
# Wandrahmsteg
# Wandsbeker Allee
# Wandsbeker Bahnhofstraße
# Wandsbeker Chaussee
# Wandsbeker Königstraße
# Wandsbeker Marktplatz
# Wandsbeker Marktstraße
# Wandsbeker Schützenhof
# Wandsbeker Stieg
# Wandsbeker Zollstraße
# Wandsedamm
# Wandseredder
# Wandsetwiete
# Wangerooger Stieg
# Warburgstraße
# Wariner Weg
# Warlimontweg
# Warnckesweg
# Warnemünder Weg
# Warnenweg
# Warnholtzstraße
# Warnstedtstraße
# Wartenau
# Wartenburger Weg
# Warthestraße
# Warwischer Hauptdeich
# Warwischer Hinterdeich
# Waseberg
# Washingtonallee
# Washingtonring
# Wasmannstraße
# Wasmerstraße
# Wasserfenchelstieg
# Wasserkamp
# Wassermannpark
# Wassermannweg
# Wasserstieg
# Waterblöcken
# Waterblöckenwiese
# Waterhörnstraße
# Waterloohain
# Waterloostraße
# Wateweg
# Wattenbergstraße
# Wattkorn
# Watzenweg
# Weberade
# Weberstraße
# Weckmannweg
# Weddestraße
# Weddinger Weg
# Wedekindstieg
# Wedeler Landstraße
# Weetenkamp
# Weg Grosslohe
# Weg Nr. 12
# Weg Nr. 173
# Weg Nr. 174
# Weg Nr. 262
# Weg Nr. 314
# Weg Nr. 320
# Weg Nr. 360
# Weg Nr. 396
# Weg Nr. 410
# Weg Nr. 414
# Weg Nr. 651
# Weg Nr. 654
# Weg Nr. 795
# Weg bei den Gärten
# Weg beim Jäger
# Wegelstück
# Wegenkamp
# Wegkoppel
# Wegzoll
# Wehlauer Weg
# Wehlbrook
# Wehmerstieg
# Wehmerweg
# Wehrdeich
# Wehrmannstraße
# Weichselmünder Straße
# Weidemoor
# Weidenallee
# Weidenbaumsweg
# Weidenbruch
# Weidendamm
# Weidende
# Weidengrasweg
# Weidenkamp
# Weidenkehre
# Weidenkoppel
# Weidenstieg
# Weiderweg
# Weidestraße
# Weidkoppel
# Weidplan
# Weidwiese
# Weiherheide
# Weimarer Straße
# Weinligstraße
# Weiselweg
# Weissenhof
# Weistritzstraße
# Weitblick
# Weizenkamp
# Weißbirkenkamp
# Weißbuchenweg
# Weißdornhof
# Weißdornweg
# Weiße Rose
# Weißenburger Straße
# Weißenseestraße
# Weißkleeweg
# Welckerstraße
# Wellingsbütteler Landstraße
# Wellingsbütteler Markt
# Wellingsbüttler Weg
# Welsestraße
# Wendemuthkai
# Wendemuthstraße
# Wendenstraße
# Wendloher Weg
# Wendlohstieg
# Wendlohstraße
# Wendrichstraße
# Wendts Weg
# Wensenbalken
# Wentorfer Straße
# Wentzelplatz
# Wentzelstraße
# Werderstraße
# Werfelring
# Werfelstieg
# Werftstraße
# Werner-Neben-Platz
# Werner-Otto-Straße
# Werner-Schroeder-Straße
# Werner-Siemens-Straße
# Werner-Witt-Straße
# Wernigeroder Weg
# Werrastieg
# Werthweg
# Weseler Weg
# Wesenbergallee
# Weserstieg
# Wespenstieg
# Wesperloh
# Wesselblek
# Wesselburer Weg
# Wesselstraat
# Wesselyring
# West-Kraueler Bogen
# Westedestieg
# Westend
# Westerfelde
# Westerheide
# Westerkamp
# Westerlandstraße
# Westerrode
# Westerweg
# Westhusenstraße
# Westphalensweg
# Westphalufer
# Westring (Straße im Bereich Friedhof Ohlsdorf keine amtl. Benennung!)
# Wetkesgarten
# Wetteringe
# Wetternstieg
# Wetternstraße
# Wettloop
# Weusthoffstraße
# Wexstraße
# Weygandtstraße
# Wibbeltweg
# Wiben-Peter-Straße
# Wichelkamp
# Wichelmannweg
# Wichelnbusch
# Wichelwisch
# Wicherns Garten
# Wichernsweg
# Wichmannstieg
# Wichmannstraße
# Wickenweg
# Widukindstraße
# Wiebekingweg
# Wiebelstraße
# Wiebischenkamp
# Wiebkestieg
# Wieckstraße
# Wiedauweg
# Wieddüp
# Wiedehopfstieg
# Wiedenthaler Bogen
# Wiedenthaler Sand
# Wielandstraße
# Wieleweg
# Wiemannweg
# Wiemerskamper Weg
# Wienbargstraße
# Wientapperweg
# Wieselstraße
# Wiesenacker
# Wiesendamm
# Wiesengrund
# Wiesenhof
# Wiesenhöfen
# Wiesenkamp
# Wiesenkehre
# Wiesenknopfstieg
# Wiesenrautenstieg
# Wiesenredder
# Wiesenstieg
# Wiesenstraße
# Wiesenweg
# Wiesingerweg
# Wiesnerring
# Wiet
# Wietersheim
# Wietreie
# Wigandweg
# Wikingerweg
# Wikingstraße
# Wildacker
# Wildbahn
# Wildbirnenhof
# Wildehovetweg
# Wildenbruchstraße
# Wildentenstieg
# Wildermuthring
# Wildes Moor
# Wildgansstraße
# Wildgrund
# Wildkatzenweg
# Wildkoppel
# Wildpfahl
# Wildrosenweg
# Wildschwanbrook
# Wildstieg
# Wildtulpenweg
# Wilhelm-Bauche-Weg
# Wilhelm-Bergner-Straße
# Wilhelm-Bock-Weg
# Wilhelm-Busch-Weg
# Wilhelm-Carstens-Weg
# Wilhelm-Drexelius-Weg
# Wilhelm-Grimm-Straße
# Wilhelm-Iwan-Kehre
# Wilhelm-Iwan-Ring
# Wilhelm-Jensen-Stieg
# Wilhelm-Lehmbruck-Straße
# Wilhelm-Lindemann-Sportanlage
# Wilhelm-Metzger-Straße
# Wilhelm-Osterhold-Stieg
# Wilhelm-Raabe-Weg
# Wilhelm-Siefke-Weg
# Wilhelm-Stein-Weg
# Wilhelm-Stille-Sportanlage
# Wilhelm-Strauß-Weg
# Wilhelm-Weber-Straße
# Wilhelmine-Hundert-Weg
# Wilhelmistraße
# Wilhelms Allee
# Wilhelmsburger Brücke
# Wilhelmsburger Inselpark
# Wilhelmsburger Platz
# Wilhelmsburger Reichsstraße
# Wilhelmsburger Straße
# Wilhelmstraße
# Wilkensweg
# Willebrandstraße
# Willerstwiete
# Willersweg
# Willhoop
# Willhöden
# Willi-Bartels-Treppe
# Willi-Hill-Weg
# Willinks Park
# Willistraße
# Willnerskamp
# Willy-Brandt-Straße
# Willy-Jacobs-Weg
# Willy-Nissen-Ring
# Willöperstraße
# Wilma-Witte-Stieg
# Wilmans Park
# Wilmansstraße
# Wilmersdorfer Straße
# Wilmshof
# Wilsdorfallee
# Wilseder Ring
# Wilsonstraße
# Wilstedter Weg
# Wilstorfer Straße
# Wilzenweg
# Wimmelsweg
# Winckelmannstraße
# Wincklerstraße
# Windeck
# Windfeld
# Windhukstraße
# Windloh
# Windmühlenstieg
# Windmühlenweg
# Windröschenweg
# Winfridweg
# Winklers Platz
# Winsbergring
# Winselohweg
# Winsener Stieg
# Winsener Straße
# Wintergrünweg
# Winterheide
# Winterhuder Kai
# Winterhuder Marktplatz
# Winterhuder Weg
# Winterlindenweg
# Winterlingstieg
# Winterstraße
# Winzeldorfer Weg
# Wischenpfad
# Wischenwinkel
# Wischhofstieg
# Wischhofsweg
# Wischhöfen
# Wismarer Straße
# Wisplerstraße
# Wisserweg
# Wittdüner Weg
# Wittekopsweg
# Wittenbergener Weg
# Wittenbergstraße
# Wittenhofstieg
# Wittenkamp
# Wittenmoor
# Witternstraße
# Wittestraße
# Wittheck
# Witthof
# Witthöfftstraße
# Wittigeck
# Wittigstieg
# Wittingstraße
# Wittkoppel
# Wittland
# Wittmoorredder
# Wittmoorstieg
# Wittmunder Weg
# Wittreem
# Wittreemkoppel
# Witts Allee
# Witts Park
# Witts Weide
# Wißmannstraße
# Woderichweg
# Woellmerstraße
# Woermannstieg
# Woermannsweg
# Wogenmannsburg
# Wohldorfer Damm
# Wohldorfer Straße
# Wohlers Allee
# Wohlersstieg
# Wohlersweg
# Wohltorfkamp
# Wohlwillstraße
# Woldsenweg
# Wolfdietrichweg
# Wolferskamp
# Wolffsonstieg
# Wolffsonweg
# Wolffstraße
# Wolfgangsweg
# Wolfrunweg
# Wolfshagen
# Wolfsloh
# Wolkausweg
# Wollgrasweg
# Wolliner Straße
# Wollkämmereistraße
# Wolsteinkamp
# Woltersstraße
# Woltmanstraße
# Woold
# Wormser Straße
# Worpsweder Stieg
# Worthdamm
# Woyrschweg
# Wragekamp
# Wrangelkoppel
# Wrangelpark
# Wrangelstraße
# Wrauster Bogen
# Wriedestraße
# Wrietkamp
# Wroostweg
# Wulffsblöcken
# Wulffsbrücke
# Wulffsgang
# Wulffsgrund
# Wulffstwiete
# Wulfsdal
# Wulfsdorfer Weg
# Wulksfelder Weg
# Wullenbusch
# Wullenbuschkoppel
# Wullenweberstieg
# Wullwisch
# Wulmsberg
# Wulmsberggrund
# Wulmstal
# Wulmstorfer Ring
# Wunderbrunnen
# Wunschring
# Wurmsweg
# Wurtkamp
# Wuthenowstraße
# Wählingsallee
# Wählingsweg
# Wöhleckebogen
# Wöhlerstraße
# Wöhren
# Wöhrenkoppel
# Wöhrenweg
# Wölberstieg
# Wölckenstraße
# Wölprie
# Wördemanns Weg
# Wördenmoorweg
# Wörenstieg
# Wöschenhof
# Wülfkenweg
# Wülpensand
# Wümmeweg
# Würffelstraße
# Wüstenkamp
# Wüsthofweg
# Wüstland
# Yokohamastraße
# Yorkstraße
# Yvonne-Mewes-Weg
# Zabelweg
# Zamenhofweg
# Zassenhausweg
# Zaunweg
# Zaunwickenweg
# Zedernweg
# Zehlendorfer Weg
# Zehntland
# Zeidlerstraße
# Zeiseweg
# Zeisigstraße
# Zeißstraße
# Zeißtwiete
# Zellerstraße
# Zellmannstraße
# Zeppelin-Park
# Zeppelinstraße
# Zesenstraße
# Zeughausmarkt
# Zeughausstraße
# Zickzackweg
# Ziegeleiweg
# Ziegelerstieg
# Ziegelerstraße
# Ziegeltwiete
# Ziegenpfad
# Ziehrerweg
# Ziesenißstraße
# Ziethenstraße
# Zikadenweg
# Zimmermannstraße
# Zimmerpforte
# Zimmerstraße
# Zinkhüttenweg
# Zinnkrautweg
# Zinnowitzer Straße
# Zippelhaus
# Zirkusweg
# Zirpenweg
# Zitadellenbrücke
# Zitadellenstraße
# Zittergrasweg
# Zitterpappelweg
# Zitzewitzstraße
# Zobelweg
# Zollamtsbogen
# Zollenbrücke
# Zollenspieker-Hauptdeich
# Zollvereinsstraße
# Zoppoter Straße
# Zu den Baumhöfen
# Zugführerweg
# Zum Ausspann
# Zum Dubben
# Zum Fürstenmoor
# Zum Golfplatz
# Zum Grasfrosch
# Zum Gutspark
# Zum Handwerkszentrum
# Zum Hünengrab
# Zum Jägerfeld
# Zum Markt
# Zum Niendorfer Grenzhaus
# Zum Wachtelkönig
# Zur Graft
# Zur Guten Hoffnung
# Zur Haidkoppel
# Zur Jenfelder Au
# Zur Kräuterwiese
# Zur Küperkoppel
# Zur Seehafenbrücke
# Zuschlagkoppel
# Zwanckweg
# Zweibrückenstraße
# Zweigweg
# Zweite Osterbrookbrücke (Südkanal)
# Zweite Twiete
# Zweiter Fersenweg
# Zwergbirkenweg
# Zwergenstieg
# Zwergfalkenweg
# Zwischen den Hecken
# Zwischen den Süderelbbrücken
# Zwischen den Zäunen
# Zylberbergstieg
# Zylberbergstraße
# Zypressenweg
# Zöllnerstraße
# Zürnerweg
# Ödenweg
# Öjendorfer Damm
# Öjendorfer Höhe
# Öjendorfer Park
# Öjendorfer Steinkamp
# Öjendorfer Weg
# Ölmühle
# Ölmühlenweg
# Ölschlägerweg
# Övelgönne
# Övelgönner Hohlweg
# Övelgönner Mühlenweg
# Övelgönner Straße
# Övern Barg
# Övern Block
# Überseeallee
# Überseeboulevard
# Überseeplatz
# Überseering
# Ünner Brandheid

# %% [markdown]
# ### tests with different libraries computing the Levenshtein Distance

# %% [markdown]
# #### 1) Levenshtein library

# %%
# T E S T  Levenshtein library :
# ratio
Levenshtein.ratio('Auto','Apfel')
# Out:
# 0.2222222222222222

# %% [markdown]
# The ratio outputs the similarity between the two input strings [0..1] (https://rawgit.com/ztane/python-Levenshtein/master/docs/Levenshtein.html#Levenshtein-ratio).

# %% [markdown]
# #### 2) difflib library

# %%
# T E S T  difflib library
# with an OCR output

# difflib's function *get_close_matches* gives the best matches among the possibilities in a list,
# sorted by similarity score, most similar first.

difflib.get_close_matches('„ame', strassen_list)
# Out:
# []

# %% [markdown]
# difflib was tested with different results from OCR - the recognized labels from the subset of the historical map (https://maps.princeton.edu/catalog/harvard-g6299-h3-1853-l5) used within the paper. Unfortunately, the library did not produce satisfying results for many recognized labels.<br><br>
# Therefore, as well as due to the fact that the Levenshtein library does not support lists as input data, we decided to make use of the **fuzzywuzzy library** which breaks through those limitations.

# %% [markdown]
# ## Levenshtein Distance
# We use the ***fuzzywuzzy*** library to get close matches within the current *strassen_list* (https://github.com/seatgeek/fuzzywuzzy). <br> <br>
# Args in *extract*: <br>
# &nbsp;    **query**: A string to match against <br>
# &nbsp;    **choices**: A list or dictionary of choices, suitable for use with
#              extract(). <br>
# &nbsp;    **processor**: Optional function for transforming choices before matching.
#                See extract(). <br>
# &nbsp;    **scorer**: Scoring function for extract(). <br>
# &nbsp;    **score_cutoff**: Optional argument for score threshold. No matches with
#                   a score less than this number will be returned. Defaults to 0. <br>
# &nbsp;    **limit**: Optional maximum for the number of elements returned. Defaults
#         to 5.

# %% [markdown]
# After the text recongnition with Tesseract OCR, all OCR results from the used historical map were put into an Excel file. We import the column containing the outputted strings ("cropped") here.

# %%
ocr_results = pd.read_excel('data/OCR_results.xlsx', header=1)
ocr_output_list = ocr_results["cropped"].tolist()
ocr_output_list
# Out:
# ['_Hollandıschey',
#  'pferdemarkg',
#  'Per e Rrgas)',
#  '_ hohe\\',
#  'klopfen markt',
#  'Adolphs Br.',
#  'Schmigdedss',
#  'ATHHAUS',
#  '[Rath',
#  '‚Schul',
#  '| MARKT',
#  'DO ke A aaa',
#  'I Beichei',
#  'HTollandısche',
#  'Catharıineıl',
#  'Nicola;',
#  'Schauenburee',
#  'St Jacob!',
#  'chopenstehl',
#  'BurstaH',
#  "Rathhau's",
#  '>Speersort|',
#  'IH ı,xt 63}',
#  'Hoplensar',
#  'OrOS|',
#  'Alter!',
#  'Gymi',
#  'SEOSSEeT',
#  'Wandrahm',
#  '.t Petry!',
#  'Breite',
#  'Reichen',
#  'Ness|',
#  "S'Cathal",
#  'Marki',
#  'kener Mandr-',
#  'ud',
#  "nas'",
#  'tacdıhaus',
#  'Brook',
#  'Str‘,',
#  'Fisch',
#  'Ce”)',
#  'Km',
#  'ho)']

# %% [markdown]
# To check one OCR output for its similarity with the current street names in *strassen_list*, we choose one string out of the *ocr_output_list*

# %%
ocr_output = ocr_output_list[4]
ocr_output
# Out:
# 'klopfen markt'

# %% [markdown]
# ### 1) partial ratio
# *fuzz.partial_ratio* computes the similarity of a possibly shorter string within parts of the longer string

# %%
partial_ratio = process.extract(ocr_output, strassen_list, scorer=fuzz.partial_ratio, limit=30)
print(partial_ratio)
# Out:
# [('Hopfenmarkt', 91), ('Marktweg', 77), ('Hopfensack', 70), ('Eppendorfer Marktplatz', 69), ('Alsterdorfer Markt', 69), ('Bergedorfer Markt', 69), ('Niendorfer Marktplatz', 69), ('Parkplatz Niendorfer Marktplatz bei Haus 24', 69), ('Zum Markt', 67), ('Koppel', 67), ('Klotzenmoor', 64), ('Poppenbüttler Markt', 62), ('Wandsbeker Marktplatz', 62), ('Hummelsbütteler Markt', 62), ('Eimsbütteler Marktplatz', 62), ('Ottenser Marktplatz', 62), ('Nienstedtener Marktplatz', 62), ('Barmbeker Markt', 62), ('Neugrabener Markt', 62), ('Veddeler Marktplatz', 62), ('Kleine Marienstraße', 62), ('Neuer Pferdemarkt', 62), ('Bahrenfelder Marktplatz', 62), ('Wellingsbütteler Markt', 62), ('Wandsbeker Marktstraße', 62), ('Flottbeker Marktweg', 62), ('Rothenburgsorter Marktplatz', 62), ('Stellinger Markt', 62), ('Klotzenmoorstieg', 62), ('Steinbeker Marktstraße', 62)]

# %%
print(len(process.extract(ocr_output, strassen_list, scorer=fuzz.partial_ratio, limit=100000)))
# Out:
# 8667

# %% [markdown]
# As fuzzywuzzy outputs too many (in this example here: 8667) possibly similar strings, we have to define further "recommendations" or conditions to narrow and improve the results from the applied levenshtein distance algorithm.<br><br>
# Also, for the subsequent approximate georeferencing - mentioned in section 3.6 within the paper - we want to extract those recognized historical labels having the best similarity to current street names - allover the historical map.

# %% [markdown]
# #### Give recommendation 1: only use matches with >= 75% out of *partial_ratio*
# The threshold at 75% is manually defined and based on empirical values from tests with different labels.

# %%
for pr in partial_ratio:
    #print(pr[1])
    if all(pr[1] < 75 for pr in partial_ratio):
        print('\033[91m', # red
              '\033[1m', # bold
              "Don't use this label for the initial georeferencing, there is no match >= 75%!",
              2*"\n",
              " SKIP IT!")
        break
    elif any(pr[1] >= 75 for pr in partial_ratio):
        print("There is at least one match with >= 75% for this label :)",
              2*"\n",
              "You can go on with this label and check for further conditions"
             )
        break
# Out:
# There is at least one match with >= 75% for this label :)
#
#  You can go on with this label and check for further conditions

# %% [markdown]
# Next, print all matches with a similarity >= 75%

# %%
partial_ratio_above75 = []

for pr in partial_ratio:
    #print(pr[1])
    if (pr[1] >= 75):
        partial_ratio_above75.append(pr)
    elif all(pr[1] < 75 for pr in partial_ratio):
        print('\033[91m', # red
              '\033[1m', # bold
              "As i said: There is no match >= 75%! :(", 2*"\n",
              " SKIP THIS LABEL!")
        break

if partial_ratio_above75: # if the list *partial_ratio_above75* is not empty...
    if len(partial_ratio_above75) == 1:
        print('\033[92m', # green
              '\033[1m', # bold
              'HOORAY!!!! The only found match is\n\n',
              partial_ratio_above75,
              '\033[0m', # end of colored bold text
              2*'\n',
              '...but please check (manually) for validity ;)'
             )
        bestmatch_partialratio = partial_ratio_above75
    else:
        bestmatch_partialratio = 0
        print("We now have", len(partial_ratio_above75), "matches on the shortlist:", 2*"\n",
              partial_ratio_above75)
# Out:
# We now have 2 matches on the shortlist:
#
#  [('Hopfenmarkt', 91), ('Marktweg', 77)]

# %% [markdown]
# #### Give recommendation 2: don't use a label if it has multiple identical best matches (e.g. 3x 85%, 5x 72%, ...)
#
# If the highest (=first) matching value does not appear twice (=second value), we can immediately define it as our best match.
#
# This condition should also eliminate labels containing frequently occurring words
# such as *Str*, *St*, *Markt*, *Am*, *Alter*, *Neuer*, *weg*, *Brücke* etc.
# because those labels would be too uncertain for the **initial** rough georeferencing

# %%
# check if the first matching value in *partial_ratio_above75* is identical to the second matching value
# --> if no: that's the string with the highest matching value and we can simply define that as the only (best) match :)
# --> if yes: go on to the next code block

if len(partial_ratio_above75) > 1: # if there is more than one match in partial_ratio_above75...
    if partial_ratio_above75[0][1] != partial_ratio_above75[1][1]: # ...and if the first match differs from the second...
        print('\033[92m', # green
              '\033[1m', # bold
              'HOORAY!!!! The only found match is\n\n',
              partial_ratio_above75[0], # ...our match is the first one in the list :)
              '\033[0m', # end of colored bold text
              2*'\n',
              '...but please check (manually) for validity ;)'
             )
        bestmatch_partialratio = partial_ratio_above75[0]
    else:
        print("Please go on with this label and have a look at other conditions")
elif len(partial_ratio_above75) == 0:
    print('\033[91m', # red
          '\033[1m', # bold
          "As i said:", 2*"\n",
          " SKIP THIS LABEL!")
elif len(partial_ratio_above75) == 1:
    print("The best match for partial ratio was already defined in the previous step:", 2*"\n",
          '\033[92m', # green
          '\033[1m', # bold
          bestmatch_partialratio)
# Out:
#   HOORAY!!!! The only found match is
#
#  ('Hopfenmarkt', 91)
#
#  ...but please check (manually) for validity ;)

# %% [markdown]
# For validation purposes: compute the numerical difference between the first and the second best match:
# - If the difference is larger than 4%, we can declare the first best match as the only best match
# - If the difference is still 0%, we should not use this recognized label as a reference point for a rough georeferencing as the similarity measure is too uncertain
# - If the difference is smaller than 4%, we should not use this recognized label as a reference point for a rough georeferencing as the similarity measure is too uncertain

# %%
if len(partial_ratio_above75) > 1:
    if partial_ratio_above75[0][1]-partial_ratio_above75[1][1] > 4: # than it's allright :)
        print("The difference between the first and second match is \n",
              '\033[1m', # bold
              abs(partial_ratio_above75[0][1]-partial_ratio_above75[1][1]), "% \n",
              '\033[0m', # end of bold text
              "and is therefore >4. Fine! :) You can use ", 
              '\033[1m', # bold
              '\033[92m', # green
              bestmatch_partialratio, 
              '\033[0m', # end of bold text
              " as the one and only best match.",
              sep = "")
    elif partial_ratio_above75[0][1]-partial_ratio_above75[1][1] == 0:
        print('\033[1m', # bold
              "Oh no. The difference between the first and second match is 0 %. This is too uncertain!", 2*"\n",
              '\033[91m', # red
              " SKIP THIS LABEL!")
    else:
        print("The difference between the first and second match is \n",
              '\033[1m', # bold
              abs(partial_ratio_above75[0][1]-partial_ratio_above75[1][1]), "% \n",
              '\033[0m', # end of bold text
              "and therefore <4. Hmmmmmmmmmmmmmm :/ Go on with the next step!",
              sep = "")
elif len(partial_ratio_above75) == 0:
    print('\033[91m', # red
          '\033[1m', # bold
          "As i said: ", 2*"\n",
          " SKIP THIS LABEL!")           
elif len(partial_ratio_above75) == 1:
    print("The best match for partial ratio was already defined in the previous step:", 2*"\n",
          '\033[92m', # green
          '\033[1m', # bold
          bestmatch_partialratio)
# Out:
# The difference between the first and second match is
# 14%
# and is therefore >4. Fine! :) You can use ('Hopfenmarkt', 91) as the one and only best match.

# %% [markdown]
# Give a last recommendation for (not) using this label as a reference point for the subsequent approximate georeferencing.

# %%
try:
    bestmatch_partialratio
    
    if bestmatch_partialratio == 0:
        print('\033[91m', # red
              '\033[1m', # bold
              "SKIP THIS LABEL!") 

    elif len(bestmatch_partialratio) > 2:
        partial_ratio_above75_df = pd.DataFrame(partial_ratio_above75,columns=['roadname','percentage'])
        #print(partial_ratio_above75_df)

        # check if duplicate values exist within *partial_ratio_above75_df['percentage']*
        # --> False = no; True = yes
        checkforduplicates = partial_ratio_above75_df.duplicated(subset=['percentage'], keep=False)
        #print(checkforduplicates)

        # if ANY percentage value is duplicate...
        # --> False = no; True = yes
        result = any(element == True for element in checkforduplicates)
        #print(result)

        # ...don't use this label for the initial georeferencing...
        if result == True:
            print('\033[91m', # red
                  '\033[1m', # bold
                  "Don't use this label for the initial georeferencing, it will be too uncertain due to multiple identical matching values!\n\n SKIP IT!")
        # ... and also not if there is no match >= 75%...
        elif partial_ratio_above75_df.empty:
            print("As I said: Don't use this label for the initial georeferencing, it will be too uncertain due to missing matches >= 75%!\n\nSKIP IT!")
        # ...if there is only one match left: that's our match!
        elif len(partial_ratio_above75_df)==1:
            print('\033[92m', # green
                  '\033[1m', # bold
                  'HOORAY!!!! The only found match is\n\n',
                  partial_ratio_above75_df.values.tolist(),
                  '\033[0m', # end of colored bold text
                  2*'\n',
                  '...but please check (manually) for validity ;)'
                 )
            bestmatch_partialratio = partial_ratio_above75_df
        # ...otherwise you can use it for further testing :)
        else:
            print("You can go on with this label and check for other conditions:", 2*"\n", partial_ratio_above75)

    else:
        print("The best match for partial ratio was already defined in the previous step:", 2*"\n",
              '\033[1m', # bold
              '\033[92m', # green
              bestmatch_partialratio)
except NameError:
    print('\033[91m', # red
          '\033[1m', # bold
          "As i said: \n\n  SKIP THIS LABEL!")
# Out:
# The best match for partial ratio was already defined in the previous step:
#
#    ('Hopfenmarkt', 91)

# %% [markdown]
# ### 2) ratio
# *fuzz.ratio* computes the Levenshtein Distance between 2 strings (= number of inserted, removed, and altered characters from string 1 to string 2)

# %%
ratio = process.extract(ocr_output, strassen_list, scorer=fuzz.ratio, limit=30)
print(ratio)
# Out:
# [('Hopfenmarkt', 83), ('Alsterdorfer Markt', 65), ('Poppenbüttler Markt', 62), ('Lohbrügger Markt', 62), ('Saseler Markt', 62), ('Hopfensack', 61), ('Bergedorfer Markt', 60), ('Klotzenmoor', 58), ('Langenhorner Markt', 58), ('Barmbeker Markt', 57), ('Sander Markt', 56), ('Ottenser Marktplatz', 56), ('Kleine Horst', 56), ('Roosens Park', 56), ('Kleine Marienstraße', 56), ('Großneumarkt', 56), ('Flottbeker Marktweg', 56), ('Lohsepark', 55), ('Zum Markt', 55), ('Kalenbarg', 55), ('Florapark', 55), ('Alter Fischmarkt', 55), ('Stellinger Markt', 55), ('Klotzenmoorstieg', 55), ('Steinbeker Markt', 55), ('Klostergarten', 54), ('Zeppelin-Park', 54), ('Lohmühlenpark', 54), ('Neugrabener Markt', 53), ('Neuer Pferdemarkt', 53)]

# %% [markdown]
# #### Give recommendation 1: only use matches with >= 60% out of *ratio*

# %% [markdown]
# We have to lower the threshold [%] here a bit because for *ratio* this value has another impact compared to *partial_ratio*
# <br>
# --> 60%
# <br><br>
# Again, this threshold was manually defined and based on empirical values from tests with different labels.

# %%
for r in ratio:
    #print(r[1])
    if all(r[1] < 60 for pr in ratio):
        print('\033[91m', # red
              '\033[1m', # bold
              "Don't use this label for the initial georeferencing, there is no match >= 60%!",
              2*"\n",
              "SKIP IT!")
        break
    elif any(r[1] >= 60 for r in ratio):
        print("There is at least one match with >= 60% for this label :)",
              2*"\n",
              "You can go on with this label and check for other conditions"
             )
        break
# Out:
# There is at least one match with >= 60% for this label :)
#
#  You can go on with this label and check for other conditions

# %% [markdown]
# Next, print all matches with a similarity >= 60%

# %%
ratio_above60 = []

for r in ratio:
    #print(r[1])
    if (r[1] >= 60):
        ratio_above60.append(r)
    elif all(r[1] < 60 for r in ratio):
        print("As i said: There is no match >= 60%! :(")
        break

if ratio_above60: # if the list *ratio_above60* is not empty...
    if len(ratio_above60) == 1:
        print('\033[92m', # green
              '\033[1m', # bold
              'HOORAY!!!! The only found match is\n\n',
              ratio_above60,
              '\033[0m', # end of colored bold text
              2*'\n',
              '...but please check (manually) for validity ;)'
             )
        bestmatch_ratio = ratio_above60
    else:
        bestmatch_ratio = 0
        print("We now have", len(ratio_above60), "matches on the shortlist:", 2*"\n",
              ratio_above60)
# Out:
# We now have 7 matches on the shortlist:
#
#  [('Hopfenmarkt', 83), ('Alsterdorfer Markt', 65), ('Poppenbüttler Markt', 62), ('Lohbrügger Markt', 62), ('Saseler Markt', 62), ('Hopfensack', 61), ('Bergedorfer Markt', 60)]

# %% [markdown]
# #### Give recommendation 2: don't use a label if it has multiple identical best matches (e.g. 3x 85%, 5x 72%, ...)
#
# This condition should also eliminate labels containing frequently occurring words
# such as *Str*, *St*, *Markt*, *Am*, *Alter*, *Neuer*, *weg*, *Brücke* etc.
# because those labels would be too uncertain for the **initial** rough georeferencing

# %%
# if the difference between the first and the second match is <= 4:
# we can put both on the shortlist

if len(ratio_above60) > 1:
    if abs(ratio_above60[0][1] - ratio_above60[1][1]) <= 4:
        bestmatch_ratio = list([ratio_above60[0], ratio_above60[1]]) # overwrite bestmatch_ratio
        print("we now have multiple matches on the shortlist:\n\n",
              '\033[1m', # bold
              bestmatch_ratio[0], bestmatch_ratio[1])
    else:
        bestmatch_ratio = list([ratio_above60[0]])
        print('\033[92m', # green
              '\033[1m', # bold
              'HOORAY!!!! The only found match is\n\n',
              bestmatch_ratio,
              '\033[0m', # end of colored bold text
              2*'\n',
              '...but please check (manually) for validity ;)'
         )
elif len(ratio_above60) == 1:
    print("The best match for ratio was already defined in the previous step:", 2*"\n",
          '\033[1m', # bold
          '\033[92m', # green
          bestmatch_ratio)
# Out:
#   HOORAY!!!! The only found match is
#
#  [('Hopfenmarkt', 83)]
#
#  ...but please check (manually) for validity ;)

# %% [markdown]
# If the highest (=first) matching value does not appear twice (=second value), we can immediately define it as our best match.

# %%
# check if the first matching value in *ratio_above60* is identical to the second matching value
# --> if no: that's the string with the highest matching value and we can simply define that as the only match :)
# --> if yes: go on to the next coding block

try:
    bestmatch_ratio 

    if len(bestmatch_ratio) > 1:
        if bestmatch_ratio[0][1] != bestmatch_ratio[1][1]:  
            print('\033[92m', # green
                    '\033[1m', # bold
                    'HOORAY!!!! The only found match is\n\n',
                    bestmatch_ratio[0],
                    '\033[0m', # end of colored bold text
                    2*'\n',
                    '...but please check (manually) for validity ;)'
                )
            bestmatch_ratio = bestmatch_ratio[0]
    else:
        print("The best match for ratio was already defined in the previous step:", 2*"\n",
              '\033[1m', # bold
              '\033[92m', # green
              bestmatch_ratio)

except NameError:
    print('\033[91m', # red
          '\033[1m', # bold
          "Don't use this label for the initial georeferencing, as there is no best match for ratio!\n\n  SKIP IT!")
# Out:
# The best match for ratio was already defined in the previous step:
#
#    [('Hopfenmarkt', 83)]

# %% [markdown]
# Give a last recommendation for (not) using this label as a reference point for the subsequent approximate georeferencing.

# %%
try:
    bestmatch_ratio 

    if len(bestmatch_ratio) > 1:
        if ratio_above60[0][1] == ratio_above60[1][1]:
            ratio_above60_df = pd.DataFrame(ratio_above60,columns=['roadname','percentage'])
            #print(ratio_above60_df)

            # check if duplicate values exist within *ratio_above60_df['percentage']*
            # --> False = no; True = yes
            checkforduplicates_r = ratio_above60_df.duplicated(subset=['percentage'], keep=False)
            #print(checkforduplicates_r)

            # if ANY percentage value is duplicate...
            # --> False = no; True = yes
            result_r = any(element == True for element in checkforduplicates_r)
            #print(result_r)

            # ...don't use this label for the initial georeferencing...
            if result_r == True:
                print('\033[91m', # red
                      '\033[1m', # bold
                      "Don't use this label for the initial georeferencing, it will be too uncertain due to", "\n",
                      " multiple identical matching values in ratio!\n\n SKIP IT!")
            # ... and also not if there is no match >= 60%...
            elif ratio_above60_df.empty:
                print("As I said: Don't use this label for the initial georeferencing, it will be too uncertain due to missing matches >= 60%!\n\nSKIP IT!")
            # ...if there is only one match left: that's our match!
            elif len(ratio_above60_df)==1:
                print('\033[92m', # green
                      '\033[1m', # bold
                      'HOORAY!!!! The only found match is\n\n',
                      ratio_above60_df.values.tolist(),
                      '\033[0m', # end of colored bold text
                      2*'\n',
                      '...but please check (manually) for validity ;)'
                     )
                bestmatch_ratio = ratio_above60_df
            # ...otherwise you can use it for further testing :)
            else:
                print("You can go on with this label and check for other conditions:", 2*" \n", ratio_above60)
        else:
            print("The best match for ratio was already defined in the previous step:", 2*"\n",
            '\033[1m', # bold
            '\033[92m', # green
            bestmatch_ratio)
    else:
        print("The best match for ratio was already defined in the previous step:", 2*"\n",
            '\033[1m', # bold
            '\033[92m', # green
            bestmatch_ratio)
        
except NameError:
    print('\033[91m', # red
          '\033[1m', # bold
          "Don't use this label for the initial georeferencing, as there is no best match for ratio!\n\n  SKIP IT!")
# Out:
# The best match for ratio was already defined in the previous step:
#
#    [('Hopfenmarkt', 83)]

# %% [markdown]
# ## compare between the results of *ratio* (*bestmatch_ratio*) and *partial_ratio* (*bestmatch_partialratio*)
# if there does not exist a distinct match until now. By doing that, we can define the best match for a recognized label from the historical map: If the best match from ratio and partial_ratio is identical, we completely trust the algorithm and define this best match as the corresponding street or place name.

# %%
#bestmatch_partialratio

# %%
#bestmatch_ratio

# %%
try:
    bestmatch_partialratio
    if type(bestmatch_partialratio) == list: # if bestmatch_partialratio is a list...
        #print('is a list')
        bestmatch_partialratio = tuple(list(itertools.chain(*bestmatch_partialratio))) # ...make a single tuple out of it.
        print(bestmatch_partialratio)
    else:
        print(bestmatch_partialratio)
except NameError:
    print('\033[91m', # red
          '\033[1m', # bold
          "I told you! You should not use this label for an initial georeferencing as there is no match for partial ratio!")
# Out:
# ('Hopfenmarkt', 91)

# %%
try:
    if type(bestmatch_ratio) == list: # if bestmatch_ratio is a list...
        bestmatch_ratio = tuple(list(itertools.chain(*bestmatch_ratio))) # ...make a single tuple out of it.
        print(bestmatch_ratio)
    else:
        print(bestmatch_ratio)
except NameError:
    print('\033[91m', # red
          '\033[1m', # bold
          "I told you! You should not use this label for an initial georeferencing as there is no match for ratio!")
# Out:
# ('Hopfenmarkt', 83)

# %%
try:
    bestmatch_partialratio
    bestmatch_ratio
    
    if bestmatch_partialratio != 0:
        if bestmatch_ratio[0] == bestmatch_partialratio[0]:
            print ('\033[1m', # bold
                   "YIPPI!!! :) The best matching strings from ratio and partial_ratio are identical:", 2*"\n",
                   '\033[92m', # green
                   bestmatch_partialratio[0], "-", bestmatch_ratio[0], 2*"\n",
                   '\033[0m', # end of colored bold text
                   "bestmatch from partial ratio:", bestmatch_partialratio[0], bestmatch_partialratio[1], "%", "\n",
                   " bestmatch from ratio:", bestmatch_ratio[0], bestmatch_ratio[1], "%", 2*"\n",
                   " and in total (sum):", bestmatch_ratio[1]+bestmatch_partialratio[1], "%", "\n"
                   "  on average:", (bestmatch_ratio[1]+bestmatch_partialratio[1])/2, "%", 2*"\n"
                   '\033[1m', # bold
                   "Use this label for an intial georeferencing!"
                  )
        else:
            print('\033[1m', # bold
                  '\033[91m', # red
                  "Go on with another label and don't use this one for the initial georeferencing \n",
                  '\033[0m', # end of colored bold text
                  "because the best matching strings from ratio and partial_ratio are not identical - therefore, it's too uncertain:",
                  2*"\n",
                  bestmatch_partialratio[0], "vs.",
                  bestmatch_ratio[0]
                 )
    elif bestmatch_partialratio == 0:
        print('\033[1m', # bold
              "There is no best match for partial ratio as it has too many similar matches.", 2*"\n",
              '\033[91m', # red
              "Don't use this label for an initial georeferencing!")
        
except NameError:
    print('\033[91m', # red
          '\033[1m', # bold
          "Don't use this label for an initial georeferencing!")
# Out:
#  YIPPI!!! :) The best matching strings from ratio and partial_ratio are identical:
#
#   Hopfenmarkt - Hopfenmarkt
#
#   bestmatch from partial ratio: Hopfenmarkt 91 %
#   bestmatch from ratio: Hopfenmarkt 83 %
#
#   and in total (sum): 174 %
#   on average: 87.0 %
#
#  Use this label for an intial georeferencing!

# %% [markdown]
# ## subsequent approximate georeferencing

# %% [markdown]
# As a following step, an approximate georeferencing (as described in the paper's section 3.6) can be performed with QGIS Georeferencer. With the help of the best overall matches (throughout the whole map), the centroids of the bounding boxes extracted in the text detection step with Strabo can be referenced to the "centroid" of the respective street or place (column 'geometry_centroid' in *strassennetz*) whose original dataset already has a coordinate system. As a result, an approximate and initial georeferencing of the historical map may be generated:
# ![georeferenced](fig06.png)
